# %% [markdown]
#
# ## Estimate differences in SSIM between registration methods within ROIs of the atlas

# %%
import bids
import os
from os.path import abspath, dirname, join
import nibabel as nib
from scipy.stats import ranksums, ttest_rel
from os.path import abspath, dirname
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.legend as legend
from nilearn.plotting import plot_anat
from matplotlib import axes as Axes
from pandas import read_excel
#%matplotlib notebook
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,10)
from wmi_nipype_workflows.wmi_nipype_workflows.utils import bids_labels
from nilearn.image import image
from nilearn.plotting import view_img, displays, plot_roi, plot_anat, show
from matplotlib.pyplot import imshow, show, figure
import numpy as np

# %%
projectdir = dirname(dirname(abspath('__file__')))
indexer=bids.layout.index.BIDSLayoutIndexer(validate=False, ignore=['code','sourcedata','tmp','tmp_mapnode'])
layout = bids.BIDSLayout(os.path.dirname(os.getcwd()), derivatives=True, validate=False, indexer=indexer)

# %%
# merge all means from relabled dil verntricle atlas of the 4 main WM tracts 
def merge_all_means(layout):
    """ Merge all calculated means of MWF or FA to a single pandas Dataframe. All TSVs with the suffix
    `means` will be queried.
    
    sub-V5574_ses-10881_roimean-jhu18m_dsc-mwf_means.tsv

    Parameters
    ----------
    layout:  BIDSLayout
        the bids-Datalayout to use

    Returns
    -------
    Dataframe with
    """
    # all .tsv files with suffix means will be found by BIDSLayout
    mean_files = layout.get(suffix='means', desc='tractssim', return_type='file', extension='.tsv')
    # Create a Dataframe
    df =pd.DataFrame()

    for mean_file in mean_files:
        mean_df = pd.read_csv(mean_file, delimiter="\t", header=0)
        labels = bids_labels(mean_file)
        
        mean_df['subject_id'] = labels['sub'] #'V5574' # Read them from filename!!!
        mean_df['session'] = labels['ses'] 
        mean_df['roimean'] = labels['roimean'] 
        mean_df['desc'] = labels['desc']
        mean_df['modality'] = labels['label']

        df = pd.concat([df, pd.DataFrame(mean_df[mean_df['# lbl'] != 0])], ignore_index=True)
        #with pd.ExcelWriter(join(layout.root, 'derivatives', 'statistik', 'means.xlsx'), engine='xlsxwriter') as writer:
        #    df.to_excel(writer)

    return df

# %%
tractmeans_df = merge_all_means(layout)
tractmeans_df.rename(columns = {'# lbl':'label_id'}, inplace = True)
tractmeans_df['label_id']=tractmeans_df['label_id'].astype(int)
tractmeans_df['label_id'].round(decimals = 0)
tractmeans_df
# Out:
#     label_id      mean       std   volume subject_id session     roimean  \
# 0          1  0.604058  0.215064  28453.0       PMD1      0m  rlbljhu18m
# 1          2  0.591777  0.190844  41883.0       PMD1      0m  rlbljhu18m
# 2          3  0.616431  0.212346  14939.0       PMD1      0m  rlbljhu18m
# 3          4  0.521639  0.213296  16826.0       PMD1      0m  rlbljhu18m
# 4          1  0.598587  0.210668  28453.0       PMD1      0m  rlbljhu18m
# 5          2  0.564896  0.184012  41883.0       PMD1      0m  rlbljhu18m
# 6          3  0.536601  0.230392  14939.0       PMD1      0m  rlbljhu18m
# 7          4  0.518646  0.211531  16826.0       PMD1      0m  rlbljhu18m
# 8          1  0.548054  0.223984  28453.0       PMD1      0m  rlbljhu18m
# 9          2  0.482714  0.211828  41883.0       PMD1      0m  rlbljhu18m
# 10         3  0.055916  0.294331  14939.0       PMD1      0m  rlbljhu18m
# 11         4  0.424661  0.271083  16826.0       PMD1      0m  rlbljhu18m
# 12         1  0.765750  0.158500  28453.0       PMD2      6m  rlbljhu18m
# 13         2  0.772571  0.165073  41883.0       PMD2      6m  rlbljhu18m
# 14         3  0.866988  0.091766  14939.0       PMD2      6m  rlbljhu18m
# 15         4  0.744090  0.148920  16826.0       PMD2      6m  rlbljhu18m
# 16         1  0.755812  0.158468  28453.0       PMD2      6m  rlbljhu18m
# 17         2  0.692002  0.218449  41883.0       PMD2      6m  rlbljhu18m
# 18         3  0.775160  0.160906  14939.0       PMD2      6m  rlbljhu18m
# 19         4  0.634409  0.213573  16826.0       PMD2      6m  rlbljhu18m
# 20         1  0.691467  0.181587  28453.0       PMD2      6m  rlbljhu18m
# 21         2  0.422872  0.314187  41883.0       PMD2      6m  rlbljhu18m
# 22         3  0.158512  0.381095  14939.0       PMD2      6m  rlbljhu18m
# 23         4  0.383180  0.283631  16826.0       PMD2      6m  rlbljhu18m
# 24         1  0.683210  0.187556  28453.0       PMD3      0m  rlbljhu18m
# 25         2  0.777800  0.154105  41883.0       PMD3      0m  rlbljhu18m
# 26         3  0.832924  0.118701  14939.0       PMD3      0m  rlbljhu18m
# 27         4  0.759531  0.142352  16826.0       PMD3      0m  rlbljhu18m
# 28         1  0.679759  0.180322  28453.0       PMD3      0m  rlbljhu18m
# 29         2  0.742198  0.174755  41883.0       PMD3      0m  rlbljhu18m
# 30         3  0.807761  0.126641  14939.0       PMD3      0m  rlbljhu18m
# 31         4  0.693376  0.180861  16826.0       PMD3      0m  rlbljhu18m
# 32         1  0.660545  0.178053  28453.0       PMD3      0m  rlbljhu18m
# 33         2  0.521991  0.304316  41883.0       PMD3      0m  rlbljhu18m
# 34         3  0.346732  0.420090  14939.0       PMD3      0m  rlbljhu18m
# 35         4  0.455180  0.325033  16826.0       PMD3      0m  rlbljhu18m
# 36         1  0.336720  0.238277  28453.0       PMD4      0m  rlbljhu18m
# 37         2  0.232414  0.303689  41883.0       PMD4      0m  rlbljhu18m
# 38         3  0.133707  0.206245  14939.0       PMD4      0m  rlbljhu18m
# 39         4  0.254085  0.224513  16826.0       PMD4      0m  rlbljhu18m
# 40         1  0.303838  0.276127  28453.0       PMD4      0m  rlbljhu18m
# 41         2  0.175963  0.287474  41883.0       PMD4      0m  rlbljhu18m
# 42         3  0.142297  0.169988  14939.0       PMD4      0m  rlbljhu18m
# 43         4  0.236390  0.220582  16826.0       PMD4      0m  rlbljhu18m
# 44         1  0.325748  0.252642  28453.0       PMD4      0m  rlbljhu18m
# 45         2  0.165161  0.282606  41883.0       PMD4      0m  rlbljhu18m
# 46         3  0.146072  0.166325  14939.0       PMD4      0m  rlbljhu18m
# 47         4  0.233129  0.219523  16826.0       PMD4      0m  rlbljhu18m
# 48         1  0.602389  0.232966  28453.0       PMD5      0m  rlbljhu18m
# 49         2  0.666183  0.220924  41883.0       PMD5      0m  rlbljhu18m
# 50         3  0.372847  0.236315  14939.0       PMD5      0m  rlbljhu18m
# 51         4  0.652743  0.168002  16826.0       PMD5      0m  rlbljhu18m
# 52         1  0.527331  0.254493  28453.0       PMD5      0m  rlbljhu18m
# 53         2  0.549141  0.283183  41883.0       PMD5      0m  rlbljhu18m
# 54         3  0.088763  0.371545  14939.0       PMD5      0m  rlbljhu18m
# 55         4  0.477095  0.304629  16826.0       PMD5      0m  rlbljhu18m
# 56         1  0.507930  0.249961  28453.0       PMD5      0m  rlbljhu18m
# 57         2  0.319035  0.357778  41883.0       PMD5      0m  rlbljhu18m
# 58         3  0.038319  0.223855  14939.0       PMD5      0m  rlbljhu18m
# 59         4  0.354797  0.372200  16826.0       PMD5      0m  rlbljhu18m
#
#          desc  modality
# 0   tractssim        fa
# 1   tractssim        fa
# 2   tractssim        fa
# 3   tractssim        fa
# 4   tractssim  multimod
# 5   tractssim  multimod
# 6   tractssim  multimod
# 7   tractssim  multimod
# 8   tractssim       t1w
# 9   tractssim       t1w
# 10  tractssim       t1w
# 11  tractssim       t1w
# 12  tractssim        fa
# 13  tractssim        fa
# 14  tractssim        fa
# 15  tractssim        fa
# 16  tractssim  multimod
# 17  tractssim  multimod
# 18  tractssim  multimod
# 19  tractssim  multimod
# 20  tractssim       t1w
# 21  tractssim       t1w
# 22  tractssim       t1w
# 23  tractssim       t1w
# 24  tractssim        fa
# 25  tractssim        fa
# 26  tractssim        fa
# 27  tractssim        fa
# 28  tractssim  multimod
# 29  tractssim  multimod
# 30  tractssim  multimod
# 31  tractssim  multimod
# 32  tractssim       t1w
# 33  tractssim       t1w
# 34  tractssim       t1w
# 35  tractssim       t1w
# 36  tractssim        fa
# 37  tractssim        fa
# 38  tractssim        fa
# 39  tractssim        fa
# 40  tractssim  multimod
# 41  tractssim  multimod
# 42  tractssim  multimod
# 43  tractssim  multimod
# 44  tractssim       t1w
# 45  tractssim       t1w
# 46  tractssim       t1w
# 47  tractssim       t1w
# 48  tractssim        fa
# 49  tractssim        fa
# 50  tractssim        fa
# 51  tractssim        fa
# 52  tractssim  multimod
# 53  tractssim  multimod
# 54  tractssim  multimod
# 55  tractssim  multimod
# 56  tractssim       t1w
# 57  tractssim       t1w
# 58  tractssim       t1w
# 59  tractssim       t1w

# %%
lookup_tract= abspath(projectdir+'/code/templates/JHU_pediatric/18month/lookup_tabel_relabel_wmtracts_edHK.xlsx')
lookup_tract = pd.read_excel(lookup_tract)
lookup_tract
# Out:
#    label_id           label_name region short_name          tract_class  \
# 0         1           Brain Stem  tract         BS           Brain Stem
# 1         2  Projection Fibers    tract         PF  Projection Fibers
# 2         3  Commissural Fibers   tract         CF  Commissural Fibers
# 3         4  Association Fibers   tract         AF  Association Fibers
#
#                                          description
# 0  Descending or ascending pathways from brain to...
# 1  Connections of cerbral cortex with thalamus, p...
# 2  Transverse connections between cerebral hemisp...
# 3  Long and short connections within cerbral cort...

# %%
# Results Tabelle 4.1
tract_df = pd.merge(left=tractmeans_df, how='left', right=lookup_tract, left_on='label_id', right_on='label_id')
tract_df=tract_df.dropna()
tract_ssim_mean= tract_df.pivot_table(index='tract_class', columns='modality', values='mean', aggfunc='mean')
tract_ssim_mean['mean']= 'mean'
tract_ssim_sd= tract_df.pivot_table(index='tract_class', columns='modality', values='mean', aggfunc='std')
tract_ssim_sd['mean']= 'sd'
tract_ssim=pd.concat([tract_ssim_mean,tract_ssim_sd])
print('PAPER SSIM VALUES \n')
print('mean SSIM within tract for different registration approach \n', tract_ssim_mean)
print('\n')
print('standard deviation SSIM within tract for different registration approach\n',tract_ssim_sd)
print('\n')
print('SSIM statistic metrics all tracts \n',tract_ssim_mean.describe())
# Out:
# PAPER SSIM VALUES
#
# mean SSIM within tract for different registration approach
#  modality                   fa  multimod       t1w  mean
# tract_class
# Association Fibers   0.586418  0.511983  0.370189  mean
# Brain Stem           0.598425  0.573065  0.546749  mean
# Commissural Fibers   0.564579  0.470116  0.149110  mean
# Projection Fibers    0.608149  0.544840  0.382355  mean
#
#
# standard deviation SSIM within tract for different registration approach
#  modality                   fa  multimod       t1w mean
# tract_class
# Association Fibers   0.208488  0.176850  0.085706   sd
# Brain Stem           0.161030  0.173210  0.145123   sd
# Commissural Fibers   0.311673  0.340724  0.122588   sd
# Projection Fibers    0.223958  0.221978  0.143522   sd
#
#
# SSIM statistic metrics all tracts
#  modality        fa  multimod       t1w
# count     4.000000  4.000000  4.000000
# mean      0.589393  0.525001  0.362101
# std       0.018779  0.044293  0.163233
# min       0.564579  0.470116  0.149110
# 25%       0.580958  0.501516  0.314919
# 50%       0.592421  0.528412  0.376272
# 75%       0.600856  0.551896  0.423453
# max       0.608149  0.573065  0.546749

# %%
t_t1w= np.array(tractmeans_df[tractmeans_df['modality']=='t1w']['mean'])
t_multi= np.array(tractmeans_df[tractmeans_df['modality']=='multimod']['mean'])
t_fa= np.array(tractmeans_df[tractmeans_df['modality']=='fa']['mean'])

# %%
# estimate t-tests for SSIM modality results 4.1
from scipy.stats import ttest_ind
print('t-test SSIM T1w against multimodal', ttest_ind(t_t1w, t_multi,  alternative='two-sided'))
print('t-test SSIM T1w against fa',ttest_ind(t_t1w, t_fa,  alternative='two-sided'))
print('t-test SSIM multi against fa', ttest_ind(t_multi, t_fa,  alternative='two-sided'))
# Out:
# t-test SSIM T1w against multimodal Ttest_indResult(statistic=-2.5169094677202297, pvalue=0.016178007716576633)
# t-test SSIM T1w against fa Ttest_indResult(statistic=-3.5845223516740696, pvalue=0.0009476571270303174)
# t-test SSIM multi against fa Ttest_indResult(statistic=-0.9334955983679408, pvalue=0.35645813106415136)
