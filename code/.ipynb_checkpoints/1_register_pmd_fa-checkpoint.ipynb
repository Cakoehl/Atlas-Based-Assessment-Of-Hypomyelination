# %% [markdown]
# # Hypomyelinating disorders:
# ### FA-based registration pipeline for atlas-based quantitative magnetic resonance imaging (qMRI) assessment

# %% [markdown]
# This nipype workflow was created to analyse pediatric qMRI images of Pelizaeus Merzbacher-Disease patients
# 1. the workflow registers all imaging files on the T1-weighted (t1w) image within the session
# 2. patient to template registration was performed using FA-images, coregistered image files get warped to the template
# 3. a brain atlas segmentation from the template will transformed to the patient session space
# 4. processed outputfiles will appear in the derivatives folder

# %%
import bids
from tqdm import tqdm
import os
from os.path import join, isfile
from nipype import Workflow
from nipype.interfaces.utility import Split, Merge
from nipype.interfaces.utility import Rename
from nipype.interfaces.io import BIDSDataGrabber, DataSink
from wmi_nipype_workflows.wmi_nipype_workflows import register_to_mni
from nipype import Node, MapNode, Workflow, IdentityInterface, Function
from nipype.interfaces.ants import N4BiasFieldCorrection
from nipype.interfaces.ants.registration import RegistrationSynQuick
from nipype.interfaces.ants.resampling import ApplyTransforms
import os
# %matplotlib notebook
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/conda/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
# set path for FSL, and ANTS package
os.environ["FSLDIR"] = "/opt/fsl/"
os.environ['ANTSPATH']='/opt/conda/bin/'

# %%
# select a patient-id and session-id for loading bids layout
subject='PMD3'
session='0m'

indexer=bids.layout.index.BIDSLayoutIndexer(validate=False, ignore=['code','tmp'])
layout = bids.BIDSLayout(os.path.dirname(os.getcwd()), derivatives=True, validate=False, indexer=indexer)

# %%
# configure inputqueries (all modalities to register) 
# file naming and file folders must follow BIDS standard
inputqueries = {
                't1w': dict(suffix='T1w', session=session, extension='nii.gz', acquisition=None, desc=None),
                'bval': dict(suffix='dwi', session=session, extension='bval' ),
                'dwi': dict(suffix='dwi', session=session, extension='nii.gz' ),
                'fa': dict(suffix='FA', session=session, extension='nii.gz', scope='derivatives', desc=None),
                't2w': dict(suffix='T2w', session=session, extension='nii.gz', acquisition=None, desc=None),
                'spgr': dict(suffix='T1w', session=session, extension='nii.gz', acquisition='SPGR'),
                'mwf': dict(suffix='mwfmap', session=session, extension='nii.gz', scope='derivatives'),
         }
optional_queries={
                'mrt': dict(suffix='mrtmap', session=session, extension='nii.gz', scope='derivatives'),
                'qt1': dict(suffix='T1map', session=session, extension='nii.gz', scope='derivatives'),
                'qt2': dict(suffix='T2map', session=session, extension='nii.gz', scope='derivatives'),
                'mt': dict(suffix='MT', session=session, extension='nii.gz', scope='derivatives', desc=None),
                'mtr': dict(suffix='MTR', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'ad': dict(suffix='AD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                'rd': dict(suffix='RD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                'md': dict(suffix='MD', session=session, extension='nii.gz', scope='derivatives', desc=None),
}

# define a dictionary containg the reference image as key (use same keys as in queries) for coregister session images and 
# list of maps to apply the warpfield on for the individual qMRI modality 
ref_image_matcher={'spgr': ['mwf', 'qt1','qt2','mrt'], # mcdespot registration target (spgr) and mcdespot maps (MWF, qT1...)
                   'b0': ['fa','rd','md'],
                   't1w': None,
                   't2w': None,
                   'mtr':['mt']                   
}

# load template as fixed (reference)images  default jhu18m 
# change the path for the T1w, T2w and a FA image as well as the atlas segmenation (mask) for using an alternativ atlas
load_fix = Node(IdentityInterface(fields=['t1','t2','fa','mask']), name='load_fix')
load_fix.inputs.t1= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t1_ss_lps.nii.gz')
load_fix.inputs.t2= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t2ax_ss_lps.nii.gz')
load_fix.inputs.fa= join(layout.root,'code','templates','JHU_pediatric','18month', 'JHU_pediatric18_SS_fa_ss_lps.nii.gz')
load_fix.inputs.mask= join(layout.root,'code','templates','JHU_pediatric','18month','dil_ventricle_atlas18m.nii.gz')

# %%
# load files for every patient
in_files = {}
queries= inputqueries
queries.update(optional_queries)   
### STEP 1 coregistrater files within the session ####
inputnode = Node(IdentityInterface(list(queries.keys())), name='inputnode')
for key in queries.keys():
        # load input files according to dict
    in_files[key] = layout.get(**queries[key], return_type='file', subject=subject, invalid_filters='allow')
    inputnode.set_input(key, in_files[key])

# %%
# files found as specified for the inputnode
print(f'found files of subject: {subject}, session: {session} for co-registration to t1w image')
inputnode.inputs
# Out:
# found files of subject: PMD3, session: 0m for co-registration to t1w image
# bval = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/dwi/sub-PMD3_ses-0m_dwi.bval']
# dwi = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/dwi/sub-PMD3_ses-0m_dwi.nii.gz']
# fa = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/DWI/sub-PMD3/ses-0m/sub-PMD3_ses-0m_FA.nii.gz']
# md = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/DWI/sub-PMD3/ses-0m/sub-PMD3_ses-0m_MD.nii.gz']
# mrt = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD3/ses-0m/sub-PMD3_ses-0m_mrtmap.nii.gz']
# mt = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/MTR/sub-PMD3/ses-0m/sub-PMD3_ses-0m_MT.nii.gz']
# mtr = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/MTR/sub-PMD3/ses-0m/sub-PMD3_ses-0m_MTR.nii.gz']
# mwf = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD3/ses-0m/sub-PMD3_ses-0m_mwfmap.nii.gz']
# qt1 = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD3/ses-0m/sub-PMD3_ses-0m_T1map.nii.gz']
# qt2 = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD3/ses-0m/sub-PMD3_ses-0m_T2map.nii.gz']
# rd = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/DWI/sub-PMD3/ses-0m/sub-PMD3_ses-0m_RD.nii.gz']
# spgr = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_acq-SPGR_T1w.nii.gz']
# t1w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T1w.nii.gz']
# t2w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T2w.nii.gz']

# %%
#squeeze= remove list from loaded files
for q in list(queries.keys()):
    squeezer= f'{q}_squeezer'
        
    globals()[squeezer]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeezer')
    #t1w_squeezer = Node(Split(splits=[1], squeeze=True), name='t1w_squeezer')

# %%
flat_list = []
for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:

                flat_list.append(v)
flat_list=list(set(flat_list))
flat_list
# Out:
# ['t1w',
#  'mt',
#  'qt2',
#  'mrt',
#  'mtr',
#  'b0',
#  'md',
#  'fa',
#  't2w',
#  'qt1',
#  'mwf',
#  'rd',
#  'spgr']

# %%
from wmi_nipype_workflows.wmi_nipype_workflows.brainextract_workflow import brain_extraction_wf
from nipype.interfaces.fsl.maths import ApplyMask
from nipype.interfaces.fsl import ImageMaths
from nipype.interfaces.fsl import BET
from nipype.interfaces.ants import N4BiasFieldCorrection
# brainextraction workflow --> robustvov get biascorrected T1w image 
brain_ex_t1 = brain_extraction_wf(report_dir=join(layout.root,'tmp','wmi_workflow_report'))
robustfov = brain_ex_t1.get_node('robustfov')
#bet = Node(BET(robust=True, mask=True, frac= 0.5), name='bet')
#bias_correction = Node(N4BiasFieldCorrection(), name="bias_correction" )

# %%
# get registration target spgrfa18 for registration of resulting mcdespot maps 
from dwi_target import get_dwi_target, get_mwf_target
mwf_target = get_mwf_target()

# %%
# generate a b0 image
b0_sink = Node(DataSink(base_directory=join(layout.root, 'derivatives', 'b0'),
                                     remove_dest_dir=True,
                                     parameterization=False),
                                     name='b0_sink')
b0_sink.inputs.container=join('sub-'+subject, 'ses-'+session)
                
# calculate b0 image for fa registration
from dti_b0 import b0_average
avg_b0 = Node(Function(input_names=['in_dwi', 'in_bval'],
                            output_names=['out_file'],
                            function=b0_average),
                         name='b0_avg')
rename_b0 = Node(Rename(format_string=("sub-{subject}_ses-{session}_space-{session}_b0"),
                                 keep_ext=True),
                          name='rename_b0')
rename_b0.inputs.subject_id= subject
rename_b0.inputs.session_id= session

# %%
coreg_sink = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_session'),
                                    remove_dest_dir=True,
                                    parameterization=False),
                            name='coreg_sink')         
coreg_sink.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
# nodes for coregister session 
for ref in list(ref_image_matcher.keys()):
    coreg= f'{ref}_coreg'
    rename_affine= f'{ref}_rename_affine'
    # nodes for coregister session 
    globals()[coreg]= Node(RegistrationSynQuick(transform_type="r"), name=f'{ref}_coreg')
    # nods for rename and save affine matrix from coregister session
    globals()[rename_affine]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-from{ref}_to_sessiont1w_xfm"),
                          keep_ext=True), name=f'{ref}_rename_affine')
    globals()[rename_affine].inputs.subject_id= subject
    globals()[rename_affine].inputs.session_id= session

# %%
# nodes for apply warp to quantitative maps
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            applyw= f'{qmrimap}_applyw'
            globals()[applyw]= Node(ApplyTransforms(), name=f'{qmrimap}_applyw')

# %%
# flatten list for ref_image_matcher.items()
flat_list = []

for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    #print(flat_list)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:
                #print('v', v)
                flat_list.append(v)
                #print(flat_list)
        
flat_list=list(set(flat_list))
flat_list
# Out:
# ['t1w',
#  'mt',
#  'qt2',
#  'mrt',
#  'mtr',
#  'b0',
#  'md',
#  'fa',
#  't2w',
#  'qt1',
#  'mwf',
#  'rd',
#  'spgr']

# %%
# adjust for different Image Dimension, otherwise brain mask cant be applied
from nilearn.image import resample_to_img
# create Node for resample all images to apply brainmask
def resampling(target, in_file): 
    import nibabel as nib
    from nilearn.image import resample_to_img
    from os.path import abspath, dirname, basename
    out_file = abspath('resampled_'+basename(in_file))
    resampled = resample_to_img(source_img=in_file, target_img=target)
    nib.save(resampled, out_file)
    return out_file

    
for image in flat_list:
    resample= f'{image}_resample'
    globals()[resample] = Node(Function(function=resampling,
                                       input_names=["target", "in_file"],
                                       output_names=["out_file"]),
                            name=f'{image}_resample')

# %%
## Apply the brainmask to the images which are registered within session
for image in flat_list:
    applymask= f'{image}_applymask'
    globals()[applymask] = Node(ApplyMask(), name=f'{image}_applymask')

# %%
for name in flat_list:
    rename= f'{name}_rename'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-t1w_desc-brainextracted_{name}"),
                          keep_ext=True), name=f'{name}_rename')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
#print(os.path.dirname(os.getcwd()))
layout.get(suffix='T1w', session='6m', subject='PMD2',extension='nii.gz', acquisition=None, desc=None)
# Out:
# [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/anat/sub-PMD2_ses-6m_T1w.nii.gz'>]

# %%
tmp = join(layout.root, 'tmp','fa', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='coreg_pmd', base_dir=tmp)
# load files and remove list (squeeze)
for qname in list(queries.keys()):
    if qname == 'spgr':
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
                     #extract spgrfa18 from 4d file
                     (spgr_squeezer, mwf_target, [('out1', 'inputnode.in_file')]),
                  ])   
    else:
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
         #[(inputnode, globals()[f'{qname}_squeezer'], [('t1w','inlist')]),
          ])
wf.connect( 
            # connect t1w image with brain extraction workflow use robustfov image as fixed image
            [(t1w_squeezer, brain_ex_t1, [('out1', 'inputnode.in_file')]),

             
             # b0 image calcuation for regsitering FA maps...
             (bval_squeezer, avg_b0, [('out1', 'in_bval')]),
             (dwi_squeezer, avg_b0, [('out1', 'in_dwi')]),
             (avg_b0, rename_b0, [('out_file', 'in_file')]),
             (rename_b0, b0_sink, [('out_file', '@b0')]),
             
 
            ])
# step 1 register images within the session to t1w image
for ref in list(ref_image_matcher.keys()):
    wf.connect( [( robustfov, globals()[f'{ref}_coreg'], [('out_roi','fixed_image')]),  

                 
                ])
    if ref=='spgr':
        wf.connect( [(mwf_target, spgr_coreg, [('outputnode.spgr_target','moving_image')]),
                    (spgr_coreg, spgr_rename_affine, [('out_matrix', 'in_file')]),
                    (spgr_rename_affine, coreg_sink, [('out_file', f'xfm.@spgr')]),
                    ])   
    elif ref=='b0':
        wf.connect( [(avg_b0, b0_coreg, [('out_file','moving_image')]),
                    (b0_coreg, b0_rename_affine, [('out_matrix', 'in_file')]),
                    (b0_rename_affine, coreg_sink, [('out_file', f'xfm.@b0')]),
                    ])       
    else:
        wf.connect( [(globals()[f'{ref}_squeezer'], globals()[f'{ref}_coreg'], [('out1','moving_image')]),
                     (globals()[f'{ref}_coreg'], globals()[f'{ref}_rename_affine'], [('out_matrix','in_file')]),
                     (globals()[f'{ref}_rename_affine'], coreg_sink, [('out_file', f'xfm.@{ref}')]),
                ])
# apply individual warpfields to qmri maps corresponding to ref_image_matcher 
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            wf.connect( [( globals()[f'{ref}_coreg'], globals()[f'{qmrimap}_applyw'], [('out_matrix', 'transforms')]),
                         ( t1w_squeezer, globals()[f'{qmrimap}_applyw'], [('out1', 'reference_image')]),
                         ( globals()[f'{qmrimap}_squeezer'], globals()[f'{qmrimap}_applyw'], [('out1', 'input_image')]),

                        ])

for name in flat_list:                         
    if  name in list(ref_image_matcher.keys()):
       # resample ref_images
        wf.connect( [(globals()[f'{name}_coreg'], globals()[f'{name}_resample'], [('warped_image', 'in_file')]), 
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                      ])
    else: # resample all maps                     
        wf.connect( [(globals()[f'{name}_applyw'], globals()[f'{name}_resample'], [('output_image', 'in_file')]),
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                    ])
# apply brainmask to all images
for name in flat_list:  
    wf.connect( [   
                     (globals()[f'{name}_resample'],globals()[f'{name}_applymask'], [('out_file', 'in_file')]), 
                         
                          #(bet, globals()[f'{qmrimap}_applymask'], [('mask_file', 'mask_file')]),
                         (brain_ex_t1, globals()[f'{name}_applymask'], [('outputnode.mask', 'mask_file')]),
                         
                         (globals()[f'{name}_applymask'],globals()[f'{name}_rename'], [('out_file', 'in_file')]), 
                         #(globals()[f'{qmrimap}_resample'], globals()[f'{qmrimap}_rename'], [('out_file', 'in_file')]), 
                         (globals()[f'{name}_rename'], coreg_sink, [('out_file', f'anat.@{name}')]),
                ])

# %%
# run nodes for registration workkflow step 1
wf.run()
# Out:
# 240130-12:07:24,389 nipype.workflow INFO:
# 	 Workflow coreg_pmd settings: ['check', 'execution', 'logging', 'monitoring']
# 240130-12:07:24,423 nipype.workflow INFO:
# 	 Running serially.
# 240130-12:07:24,424 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/t1w_squeezer".
# 240130-12:07:24,425 nipype.workflow INFO:
# 	 [Node] Executing "t1w_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,426 nipype.workflow INFO:
# 	 [Node] Finished "t1w_squeezer", elapsed time 0.000243s.
# 240130-12:07:24,429 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.bval_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/bval_squeezer".
# 240130-12:07:24,430 nipype.workflow INFO:
# 	 [Node] Executing "bval_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,431 nipype.workflow INFO:
# 	 [Node] Finished "bval_squeezer", elapsed time 0.00021s.
# 240130-12:07:24,432 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.dwi_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/dwi_squeezer".
# 240130-12:07:24,434 nipype.workflow INFO:
# 	 [Node] Executing "dwi_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,435 nipype.workflow INFO:
# 	 [Node] Finished "dwi_squeezer", elapsed time 0.000265s.
# 240130-12:07:24,437 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/fa_squeezer".
# 240130-12:07:24,439 nipype.workflow INFO:
# 	 [Node] Executing "fa_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,441 nipype.workflow INFO:
# 	 [Node] Finished "fa_squeezer", elapsed time 0.000338s.
# 240130-12:07:24,443 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/t2w_squeezer".
# 240130-12:07:24,604 nipype.workflow INFO:
# 	 [Node] Executing "t2w_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,606 nipype.workflow INFO:
# 	 [Node] Finished "t2w_squeezer", elapsed time 0.00026s.
# 240130-12:07:24,608 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/spgr_squeezer".
# 240130-12:07:24,610 nipype.workflow INFO:
# 	 [Node] Executing "spgr_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,611 nipype.workflow INFO:
# 	 [Node] Finished "spgr_squeezer", elapsed time 0.000236s.
# 240130-12:07:24,613 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mwf_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/mwf_squeezer".
# 240130-12:07:24,614 nipype.workflow INFO:
# 	 [Node] Executing "mwf_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,615 nipype.workflow INFO:
# 	 [Node] Finished "mwf_squeezer", elapsed time 0.000232s.
# 240130-12:07:24,617 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mrt_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/mrt_squeezer".
# 240130-12:07:24,618 nipype.workflow INFO:
# 	 [Node] Executing "mrt_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,619 nipype.workflow INFO:
# 	 [Node] Finished "mrt_squeezer", elapsed time 0.000222s.
# 240130-12:07:24,621 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.qt1_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/qt1_squeezer".
# 240130-12:07:24,623 nipype.workflow INFO:
# 	 [Node] Executing "qt1_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,624 nipype.workflow INFO:
# 	 [Node] Finished "qt1_squeezer", elapsed time 0.000298s.
# 240130-12:07:24,626 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.qt2_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/qt2_squeezer".
# 240130-12:07:24,627 nipype.workflow INFO:
# 	 [Node] Executing "qt2_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,628 nipype.workflow INFO:
# 	 [Node] Finished "qt2_squeezer", elapsed time 0.00021s.
# 240130-12:07:24,630 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mt_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/mt_squeezer".
# 240130-12:07:24,632 nipype.workflow INFO:
# 	 [Node] Executing "mt_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,633 nipype.workflow INFO:
# 	 [Node] Finished "mt_squeezer", elapsed time 0.000208s.
# 240130-12:07:24,635 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mtr_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/mtr_squeezer".
# 240130-12:07:24,637 nipype.workflow INFO:
# 	 [Node] Executing "mtr_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,638 nipype.workflow INFO:
# 	 [Node] Finished "mtr_squeezer", elapsed time 0.000219s.
# 240130-12:07:24,641 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.rd_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/rd_squeezer".
# 240130-12:07:24,644 nipype.workflow INFO:
# 	 [Node] Executing "rd_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,646 nipype.workflow INFO:
# 	 [Node] Finished "rd_squeezer", elapsed time 0.000316s.
# 240130-12:07:24,650 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.md_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/md_squeezer".
# 240130-12:07:24,653 nipype.workflow INFO:
# 	 [Node] Executing "md_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-12:07:24,655 nipype.workflow INFO:
# 	 [Node] Finished "md_squeezer", elapsed time 0.000296s.
# 240130-12:07:24,658 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.n4correction" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/n4correction".
# 240130-12:07:24,660 nipype.workflow INFO:
# 	 [Node] Executing "n4correction" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240130-12:09:03,385 nipype.workflow INFO:
# 	 [Node] Finished "n4correction", elapsed time 98.719274s.
# 240130-12:09:03,389 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.subject_id_node" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/subject_id_node".
# 240130-12:09:03,391 nipype.workflow INFO:
# 	 [Node] Executing "subject_id_node" <nipype.interfaces.utility.wrappers.Function>
# 240130-12:09:03,393 nipype.workflow INFO:
# 	 [Node] Finished "subject_id_node", elapsed time 0.000446s.
# 240130-12:09:03,396 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_avg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg".
# 240130-12:09:03,399 nipype.workflow INFO:
# 	 [Node] Executing "b0_avg" <nipype.interfaces.utility.wrappers.Function>
# 240130-12:09:03,982 nipype.workflow INFO:
# 	 [Node] Finished "b0_avg", elapsed time 0.581611s.
# 240130-12:09:03,985 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_target.split_spgr" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/spgr_target/split_spgr".
# 240130-12:09:03,990 nipype.workflow INFO:
# 	 [Node] Executing "split_spgr" <nipype.interfaces.fsl.utils.Split>
# 240130-12:09:05,497 nipype.workflow INFO:
# 	 [Node] Finished "split_spgr", elapsed time 1.504983s.
# 240130-12:09:05,501 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.robustfov" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov".
# 240130-12:09:05,504 nipype.workflow INFO:
# 	 [Node] Executing "robustfov" <wmi_nipype_workflows.wmi_nipype_workflows.brainextract_workflow.RobustFOVadv>
# 240130-12:09:07,854 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:07.853888:Final FOV is:
# 240130-12:09:07,856 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:07.853888:0.000000 144.000000 0.000000 224.000000 49.000000 170.000000
# 240130-12:09:07,857 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:07.853888:
# 240130-12:09:08,16 nipype.workflow INFO:
# 	 [Node] Finished "robustfov", elapsed time 2.511113s.
# 240130-12:09:08,19 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.rename_b0" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/rename_b0".
# 240130-12:09:08,25 nipype.workflow INFO:
# 	 [Node] Executing "rename_b0" <nipype.interfaces.utility.base.Rename>
# 240130-12:09:08,28 nipype.workflow INFO:
# 	 [Node] Finished "rename_b0", elapsed time 0.000764s.
# 240130-12:09:08,31 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_target.get_target" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/spgr_target/get_target".
# 240130-12:09:08,37 nipype.workflow INFO:
# 	 [Node] Executing "get_target" <nipype.interfaces.utility.wrappers.Function>
# 240130-12:09:08,40 nipype.workflow INFO:
# 	 [Node] Finished "get_target", elapsed time 0.000762s.
# 240130-12:09:08,43 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_coreg".
# 240130-12:09:08,49 nipype.workflow INFO:
# 	 [Node] Executing "b0_coreg" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 240130-12:09:08,107 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673:
# 240130-12:09:08,110 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673:--------------------------------------------------------------------------------------
# 240130-12:09:08,111 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Mapping parameters
# 240130-12:09:08,112 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673:--------------------------------------------------------------------------------------
# 240130-12:09:08,112 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: ANTSPATH is /opt/conda/bin/
# 240130-12:09:08,113 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673:
# 240130-12:09:08,114 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Dimensionality:           3
# 240130-12:09:08,115 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Output name prefix:       transform
# 240130-12:09:08,116 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Fixed images:             /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-12:09:08,116 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Moving images:            /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg/sub-PMD3_ses-0m_dwi_avg_b0.nii.gz
# 240130-12:09:08,117 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Mask images:
# 240130-12:09:08,118 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Initial transforms:
# 240130-12:09:08,119 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Number of threads:        1
# 240130-12:09:08,120 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Spline distance:          26
# 240130-12:09:08,120 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Transform type:           r
# 240130-12:09:08,121 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: MI histogram bins:        32
# 240130-12:09:08,122 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Precision:                d
# 240130-12:09:08,123 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673: Use histogram matching    0
# 240130-12:09:08,124 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.107673:======================================================================================
# 240130-12:09:08,284 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.284714: antsRegistration call:
# 240130-12:09:08,286 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.284714:--------------------------------------------------------------------------------------
# 240130-12:09:08,287 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.287144:/opt/conda/bin//antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [transform,transformWarped.nii.gz,transformInverseWarped.nii.gz] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [0.005,0.995] --initial-moving-transform [/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg/sub-PMD3_ses-0m_dwi_avg_b0.nii.gz,1] --transform Rigid[0.1] --metric MI[/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg/sub-PMD3_ses-0m_dwi_avg_b0.nii.gz,1,32,Regular,0.25] --convergence [1000x500x250x0,1e-6,10] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# 240130-12:09:08,288 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.287144:--------------------------------------------------------------------------------------
# 240130-12:09:08,311 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.311211:All_Command_lines_OK
# 240130-12:09:08,312 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.311211:Using double precision for computations.
# 240130-12:09:08,547 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.547164:=============================================================================
# 240130-12:09:08,548 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.547164:The composite transform comprises the following transforms (in order):
# 240130-12:09:08,549 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.547164:  1. Center of mass alignment using fixed image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz and moving image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg/sub-PMD3_ses-0m_dwi_avg_b0.nii.gz (type = Euler3DTransform)
# 240130-12:09:08,550 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.547164:=============================================================================
# 240130-12:09:08,552 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.552131:  number of levels = 4
# 240130-12:09:08,552 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.552131:  fixed image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-12:09:08,553 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.552131:  moving image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/b0_avg/sub-PMD3_ses-0m_dwi_avg_b0.nii.gz
# 240130-12:09:08,713 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Dimension = 3
# 240130-12:09:08,714 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Number of stages = 1
# 240130-12:09:08,715 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Use Histogram Matching false
# 240130-12:09:08,716 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Winsorize image intensities true
# 240130-12:09:08,717 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Lower quantile = 0.005
# 240130-12:09:08,717 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Upper quantile = 0.995
# 240130-12:09:08,718 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:Stage 1 State
# 240130-12:09:08,719 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.713067:   Image metric = Mattes
# 240130-12:09:08,722 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Fixed image = Image (0x55db1893ce70)
# 240130-12:09:08,723 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RTTI typeinfo:   itk::Image<double, 3u>
# 240130-12:09:08,724 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Reference Count: 2
# 240130-12:09:08,724 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Modified Time: 1560
# 240130-12:09:08,725 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Debug: Off
# 240130-12:09:08,726 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Object Name:
# 240130-12:09:08,727 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Observers:
# 240130-12:09:08,727 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    none
# 240130-12:09:08,728 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Source: (none)
# 240130-12:09:08,729 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Source output name: (none)
# 240130-12:09:08,730 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Release Data: Off
# 240130-12:09:08,730 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Data Released: False
# 240130-12:09:08,731 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Global Release Data: Off
# 240130-12:09:08,732 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PipelineMTime: 0
# 240130-12:09:08,733 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  UpdateMTime: 1369
# 240130-12:09:08,733 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RealTimeStamp: 0 seconds
# 240130-12:09:08,734 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  LargestPossibleRegion:
# 240130-12:09:08,734 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,735 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,736 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [144, 224, 170]
# 240130-12:09:08,736 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  BufferedRegion:
# 240130-12:09:08,737 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,737 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,738 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [144, 224, 170]
# 240130-12:09:08,739 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RequestedRegion:
# 240130-12:09:08,743 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,744 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,744 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [144, 224, 170]
# 240130-12:09:08,745 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Spacing: [1, 1, 1]
# 240130-12:09:08,745 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Origin: [72.8494, 111, -115.783]
# 240130-12:09:08,746 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Direction:
# 240130-12:09:08,746 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-1 0 0
# 240130-12:09:08,747 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 -1 0
# 240130-12:09:08,747 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 0 1
# 240130-12:09:08,748 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,748 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  IndexToPointMatrix:
# 240130-12:09:08,749 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-1 0 0
# 240130-12:09:08,749 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 -1 0
# 240130-12:09:08,750 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 0 1
# 240130-12:09:08,750 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,750 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PointToIndexMatrix:
# 240130-12:09:08,751 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-1 0 0
# 240130-12:09:08,751 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 -1 0
# 240130-12:09:08,752 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 0 1
# 240130-12:09:08,752 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,753 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Inverse Direction:
# 240130-12:09:08,753 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-1 0 0
# 240130-12:09:08,754 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 -1 0
# 240130-12:09:08,754 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0 0 1
# 240130-12:09:08,755 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,755 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PixelContainer:
# 240130-12:09:08,755 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    ImportImageContainer (0x55db1891f360)
# 240130-12:09:08,756 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
# 240130-12:09:08,756 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Reference Count: 1
# 240130-12:09:08,757 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Modified Time: 1366
# 240130-12:09:08,757 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Debug: Off
# 240130-12:09:08,758 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Object Name:
# 240130-12:09:08,758 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Observers:
# 240130-12:09:08,758 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:        none
# 240130-12:09:08,759 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Pointer: 0x7f6d3fb1a010
# 240130-12:09:08,759 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Container manages memory: true
# 240130-12:09:08,760 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Size: 5483520
# 240130-12:09:08,760 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Capacity: 5483520
# 240130-12:09:08,761 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,761 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Moving image = Image (0x55db1894de80)
# 240130-12:09:08,765 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RTTI typeinfo:   itk::Image<double, 3u>
# 240130-12:09:08,765 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Reference Count: 2
# 240130-12:09:08,766 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Modified Time: 1561
# 240130-12:09:08,766 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Debug: Off
# 240130-12:09:08,766 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Object Name:
# 240130-12:09:08,767 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Observers:
# 240130-12:09:08,767 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    none
# 240130-12:09:08,768 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Source: (none)
# 240130-12:09:08,768 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Source output name: (none)
# 240130-12:09:08,768 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Release Data: Off
# 240130-12:09:08,769 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Data Released: False
# 240130-12:09:08,769 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Global Release Data: Off
# 240130-12:09:08,770 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PipelineMTime: 0
# 240130-12:09:08,770 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  UpdateMTime: 1558
# 240130-12:09:08,770 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RealTimeStamp: 0 seconds
# 240130-12:09:08,771 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  LargestPossibleRegion:
# 240130-12:09:08,772 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,773 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,773 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [104, 104, 64]
# 240130-12:09:08,774 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  BufferedRegion:
# 240130-12:09:08,774 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,774 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,775 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [104, 104, 64]
# 240130-12:09:08,775 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  RequestedRegion:
# 240130-12:09:08,775 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Dimension: 3
# 240130-12:09:08,776 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Index: [0, 0, 0]
# 240130-12:09:08,776 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    Size: [104, 104, 64]
# 240130-12:09:08,776 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Spacing: [2, 2, 2]
# 240130-12:09:08,777 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Origin: [-101.932, 84.2236, -104.864]
# 240130-12:09:08,777 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Direction:
# 240130-12:09:08,777 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.999617 0.00694552 -0.0267869
# 240130-12:09:08,778 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.0139686 -0.962261 0.27177
# 240130-12:09:08,778 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.0238884 0.27204 0.961989
# 240130-12:09:08,778 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,779 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  IndexToPointMatrix:
# 240130-12:09:08,779 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:1.99923 0.013891 -0.0535738
# 240130-12:09:08,779 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.0279373 -1.92452 0.54354
# 240130-12:09:08,780 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.0477768 0.54408 1.92398
# 240130-12:09:08,780 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,780 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PointToIndexMatrix:
# 240130-12:09:08,781 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.499809 0.00698432 0.0119442
# 240130-12:09:08,781 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.00347276 -0.48113 0.13602
# 240130-12:09:08,782 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-0.0133935 0.135885 0.480995
# 240130-12:09:08,782 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,782 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  Inverse Direction:
# 240130-12:09:08,783 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.999617 0.0139686 0.0238884
# 240130-12:09:08,783 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:0.00694552 -0.962261 0.27204
# 240130-12:09:08,783 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:-0.0267869 0.27177 0.961989
# 240130-12:09:08,784 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,784 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  PixelContainer:
# 240130-12:09:08,784 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:    ImportImageContainer (0x55db18944a90)
# 240130-12:09:08,785 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
# 240130-12:09:08,785 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Reference Count: 1
# 240130-12:09:08,785 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Modified Time: 1555
# 240130-12:09:08,786 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Debug: Off
# 240130-12:09:08,786 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Object Name:
# 240130-12:09:08,786 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Observers:
# 240130-12:09:08,787 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:        none
# 240130-12:09:08,787 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Pointer: 0x55db18956290
# 240130-12:09:08,787 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Container manages memory: true
# 240130-12:09:08,788 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Size: 692224
# 240130-12:09:08,791 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:      Capacity: 692224
# 240130-12:09:08,791 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,792 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Weighting = 1
# 240130-12:09:08,792 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Sampling strategy = regular
# 240130-12:09:08,792 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Number of bins = 32
# 240130-12:09:08,793 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Radius = 4
# 240130-12:09:08,793 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Sampling percentage  = 0.25
# 240130-12:09:08,794 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:   Transform = Rigid
# 240130-12:09:08,794 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Gradient step = 0.1
# 240130-12:09:08,794 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Update field sigma (voxel space) = 0
# 240130-12:09:08,795 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Total field sigma (voxel space) = 0
# 240130-12:09:08,795 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Update field time sigma = 0
# 240130-12:09:08,795 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Total field time sigma  = 0
# 240130-12:09:08,796 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Number of time indices = 0
# 240130-12:09:08,796 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:     Number of time point samples = 0
# 240130-12:09:08,796 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:Registration using 1 total stages.
# 240130-12:09:08,797 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:
# 240130-12:09:08,797 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:Stage 0
# 240130-12:09:08,797 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  iterations = 1000x500x250x0
# 240130-12:09:08,798 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  convergence threshold = 1e-06
# 240130-12:09:08,798 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  convergence window size = 10
# 240130-12:09:08,798 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  number of levels = 4
# 240130-12:09:08,799 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.722166:  using the Mattes MI metric (number of bins = 32, weight = 1)
# 240130-12:09:08,970 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.970631:  preprocessing:  winsorizing the image intensities
# 240130-12:09:08,972 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.970631:  Shrink factors (level 1 out of 4): [8, 8, 8]
# 240130-12:09:08,973 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08.970631:  Shrink factors (level 2 out of 4): [4, 4, 4]
# 240130-12:09:08,974 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:08
nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:21.690300:Total elapsed time: 1.2977e+01
# 240130-12:09:23,317 nipype.workflow INFO:
# 	 [Node] Finished "b0_coreg", elapsed time 15.262867s.
# 240130-12:09:23,322 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/t1w_coreg".
# 240130-12:09:23,326 nipype.workflow INFO:
# 	 [Node] Executing "t1w_coreg" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 240130-12:09:23,379 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122:
# 240130-12:09:23,381 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122:--------------------------------------------------------------------------------------
# 240130-12:09:23,382 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Mapping parameters
# 240130-12:09:23,383 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122:--------------------------------------------------------------------------------------
# 240130-12:09:23,384 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: ANTSPATH is /opt/conda/bin/
# 240130-12:09:23,385 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122:
# 240130-12:09:23,387 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Dimensionality:           3
# 240130-12:09:23,388 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Output name prefix:       transform
# 240130-12:09:23,389 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Fixed images:             /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-12:09:23,390 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Moving images:            /home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T1w.nii.gz
# 240130-12:09:23,391 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Mask images:
# 240130-12:09:23,392 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Initial transforms:
# 240130-12:09:23,393 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Number of threads:        1
# 240130-12:09:23,394 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Spline distance:          26
# 240130-12:09:23,395 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Transform type:           r
# 240130-12:09:23,395 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: MI histogram bins:        32
# 240130-12:09:23,396 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Precision:                d
# 240130-12:09:23,397 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122: Use histogram matching    0
# 240130-12:09:23,398 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.379122:======================================================================================
# 240130-12:09:23,553 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.553522: antsRegistration call:
# 240130-12:09:23,554 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.553522:--------------------------------------------------------------------------------------
# 240130-12:09:23,556 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.556400:/opt/conda/bin//antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [transform,transformWarped.nii.gz,transformInverseWarped.nii.gz] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [0.005,0.995] --initial-moving-transform [/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T1w.nii.gz,1] --transform Rigid[0.1] --metric MI[/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T1w.nii.gz,1,32,Regular,0.25] --convergence [1000x500x250x0,1e-6,10] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# 240130-12:09:23,557 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.556400:--------------------------------------------------------------------------------------
# 240130-12:09:23,579 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.579329:All_Command_lines_OK
# 240130-12:09:23,580 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.579329:Using double precision for computations.
# 240130-12:09:23,977 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.977769:=============================================================================
# 240130-12:09:23,979 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.977769:The composite transform comprises the following transforms (in order):
# 240130-12:09:23,980 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.977769:  1. Center of mass alignment using fixed image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz and moving image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD3/ses-0m/anat/sub-PMD3_ses-0m_T1w.nii.gz (type = Euler3DTransform)
# 240130-12:09:23,981 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.977769:=============================================================================
# 240130-12:09:23,982 nipype.interface INFO:
# 	 stdout 2024-01-30T12:09:23.982916:  number of levels = 4
# 240130-12:09:23,983 nipype.interface INFO:
# ...
# 240130-12:10:29,436 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.436901: 2DIAGNOSTIC,    66, -6.897434138318e-01, 5.078010123271e-04, 2.8802e+00, 5.9769e-03,
# 240130-12:10:29,444 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.444192: 2DIAGNOSTIC,    67, -7.033765713717e-01, 5.403796798723e-04, 2.8875e+00, 7.2751e-03,
# 240130-12:10:29,451 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.451518: 2DIAGNOSTIC,    68, -7.073291014235e-01, 5.841793106897e-04, 2.8949e+00, 7.3869e-03,
# 240130-12:10:29,477 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.477795: 2DIAGNOSTIC,    69, -7.090626708805e-01, 6.126481094170e-04, 2.9210e+00, 2.6180e-02,
# 240130-12:10:29,483 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.483775: 2DIAGNOSTIC,    70, -7.090625512798e-01, 5.967342532278e-04, 2.9270e+00, 5.9700e-03,
# 240130-12:10:29,489 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.489760: 2DIAGNOSTIC,    71, -7.090632510776e-01, 5.521384275713e-04, 2.9331e+00, 6.0420e-03,
# 240130-12:10:29,495 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.495617: 2DIAGNOSTIC,    72, -7.090644338309e-01, 4.763260092621e-04, 2.9389e+00, 5.8470e-03,
# 240130-12:10:29,501 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.501430: 2DIAGNOSTIC,    73, -7.090664361699e-01, 3.884792176452e-04, 2.9446e+00, 5.7311e-03,
# 240130-12:10:29,507 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.507122: 2DIAGNOSTIC,    74, -7.090698637067e-01, 2.798362572984e-04, 2.9504e+00, 5.7490e-03,
# 240130-12:10:29,512 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.512883: 2DIAGNOSTIC,    75, -7.090757644258e-01, 1.608481825323e-04, 2.9561e+00, 5.6810e-03,
# 240130-12:10:29,518 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.518583: 2DIAGNOSTIC,    76, -7.090857214825e-01, 4.528036730377e-05, 2.9618e+00, 5.6930e-03,
# 240130-12:10:29,524 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.524205: 2DIAGNOSTIC,    77, -7.091024133305e-01, 1.148417018988e-05, 2.9674e+00, 5.6820e-03,
# 240130-12:10:29,530 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.530094: 2DIAGNOSTIC,    78, -7.091302880875e-01, 1.220519634429e-06, 2.9732e+00, 5.8119e-03,
# 240130-12:10:29,535 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.535878: 2DIAGNOSTIC,    79, -7.091765082281e-01, 1.705498160155e-06, 2.9790e+00, 5.7700e-03,
# 240130-12:10:29,542 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.542771: 2DIAGNOSTIC,    80, -7.092521078841e-01, 2.491989423675e-06, 2.9859e+00, 6.8860e-03,
# 240130-12:10:29,548 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:29.548558: 2DIAGNOSTIC,    81, -7.093557737444e-01, 3.651666974983e-06, 2.9917e+00, 5.7781e-03,
# 240130-12:10:31,37 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:31.037278:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-12:10:31,38 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:31.037278: 2DIAGNOSTIC,     1, -6.074574768810e-01, 1.797693134862e+308, 4.4804e+00, 1.4887e+00,
# 240130-12:10:31,104 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10
nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:48.294057: 2DIAGNOSTIC,    23, -5.912555352507e-01, 4.677225913366e-06, 2.1736e+01, 5.7968e-01,
# 240130-12:10:49,86 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:49.086623: 2DIAGNOSTIC,    24, -5.912584091390e-01, 3.780623257524e-06, 2.2528e+01, 7.9255e-01,
# 240130-12:10:49,565 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:49.565109: 2DIAGNOSTIC,    25, -5.912588653335e-01, 3.018691952954e-06, 2.3007e+01, 4.7847e-01,
# 240130-12:10:50,160 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:50.159982: 2DIAGNOSTIC,    26, -5.912577509575e-01, 2.347387174702e-06, 2.3602e+01, 5.9489e-01,
# 240130-12:10:50,655 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:50.655104: 2DIAGNOSTIC,    27, -5.912583974142e-01, 1.915170638710e-06, 2.4097e+01, 4.9506e-01,
# 240130-12:10:51,681 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:51.681880: 2DIAGNOSTIC,    28, -5.912620072383e-01, 1.977994571481e-06, 2.5123e+01, 1.0267e+00,
# 240130-12:10:54,128 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:54.128501: 2DIAGNOSTIC,    29, -5.912608681660e-01, 1.814405111544e-06, 2.7570e+01, 2.4467e+00,
# 240130-12:10:56,573 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:56.572933: 2DIAGNOSTIC,    30, -5.912608681640e-01, 1.646860713939e-06, 3.0015e+01, 2.4444e+00,
# 240130-12:10:57,278 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:57.277942: 2DIAGNOSTIC,    31, -5.912608681640e-01, 1.255901106251e-06, 3.0720e+01, 7.0500e-01,
# 240130-12:10:57,874 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:57.874133: 2DIAGNOSTIC,    32, -5.912608681640e-01, 1.159220830410e-06, 3.1316e+01, 5.9615e-01,
# 240130-12:10:58,685 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:58.685613: 2DIAGNOSTIC,    33, -5.912608681640e-01, 1.071935908772e-06, 3.2127e+01, 8.1141e-01,
# 240130-12:10:59,286 nipype.interface INFO:
# 	 stdout 2024-01-30T12:10:59.286537: 2DIAGNOSTIC,    34, -5.912608681640e-01, 1.020112418856e-06, 3.2728e+01, 6.0088e-01,
# 240130-12:11:02,759 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.759017:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-12:11:02,760 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.759017: 2DIAGNOSTIC,     1, -5.186451520935e-01, 1.797693134862e+308, 3.6200e+01, 3.4725e+00,
# 240130-12:11:02,761 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.759017:  Elapsed time (stage 0): 3.6714e+01
# 240130-12:11:02,762 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.759017:
# 240130-12:11:02,769 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.769164:
# 240130-12:11:02,769 nipype.interface INFO:
# 	 stdout 2024-01-30T12:11:02.769164:Total elapsed time: 3.6734e+01
# 240130-12:11:05,305 nipype.workflow INFO:
# 	 [Node] Finished "mtr_coreg", elapsed time 40.110194s.
# 240130-12:11:05,315 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.bet" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/fa/sub-PMD3/ses-0m/coreg_pmd/brain_extraction/bet".
# 240130-12:11:05,318 nipype.workflow INFO:
# 	 [Node] Executing "bet" <nipype.interfaces.fsl.preprocess.BET>

# %%
# create a dataset_description.json for derivatives 'coreg_session'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_session', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
        'Name': 'register session files on t1w image',
        'BIDSVersion': '1.4.0',
        'DatasetType': 'derivative',
        'GeneratedBy': [{'caroline.koehler@ukdd.de': 'co-register session images to T1-weighted image of the session'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_session', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_session Workflow')
# update layout otherwise coreg_session files are not found)

try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'coreg_session'))
    print ('writing dataset_description for derivatives coreg_session')

except:
    print('dataset_description exists ')

# %%
print('warp atlas in PMD space')
### STEP2: warp the jhu18m atlas in pmd patient space ###
print('reload bids layout')
layout2 = bids.BIDSLayout(layout.root, derivatives=True, validate=False, ignore=['code','tmp', 'tmp_t1w','tmp_fa','tmp_multimod'])

# %%
flat_list

# %%
load_coreg = Node(IdentityInterface(flat_list), name='inputnode2')
for name in flat_list:
    in_files= layout2.get(suffix=name, subject=subject, session=session, acquisition=None, scope='derivatives', desc='brainextracted', extension='nii.gz')
    load_coreg.set_input(name, in_files)

# %%
# shows all found coregistered and brainextracted images of the subject and session
print(f'list of files found for registration step 2 of subject:{subject}' )
load_coreg.inputs

# %%
# create multiple nodes squeeze= remove list from loaded files
for q in flat_list:
    squeez= f'{q}_squeez'
    globals()[squeez]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeez')

# %%
# merge files to list
merge_inputs=len(flat_list)# dynamic number of connections in for merge node
pmd_coregimages=Node(Merge(merge_inputs), name='pmd_coregimages') # make a list of images to use Mapnodes

# %%
# apply inverse warp field on jhu atlas/ mask
# this workflow register the moving image to a template (reference image) and apply an inverse transform to the atlas segmentation
# this warps the altas segmentation in the patient session space 
# Additionally, pmd_coreg_images get warped to jhu template
from wmi_nipype_workflows.wmi_nipype_workflows.register_to_mni import mask_to_patient_space
mask_to_pmd = mask_to_patient_space()

# %%
# split inv_mask because it is a list (mapnode)
split_inv_mask= Node(Split(), name= 'split_inv_mask')
split_inv_mask.inputs.splits= [1]
split_inv_mask.inputs.squeeze= True

# %%
# apply transforms on pmd_coregimages
# all coregistered files are also moved to template space fascilitating patient comparison
from nipype.interfaces.ants import ApplyTransforms, RegistrationSynQuick
apply_transforms_forw= MapNode(ApplyTransforms(), name = 'apply_transforms_forw', iterfield = ['input_image'])
transforms = Node(Merge(2), name='transforms')
split_pmd_forw = Node(Split(), name= 'split_pmd_forw')
split_pmd_forw.inputs.splits= [1]*merge_inputs
split_pmd_forw.inputs.squeeze= True

# %%
# rename and save jhu18m atlas/mask in pmd space
jhu_to_pmd_fa = Node(DataSink(base_directory=join(layout.root,'derivatives', 'jhu18m_to_pmd_fa'),
                           remove_dest_dir=True,
                            parameterization=False), name='jhu_to_pmd_fa')
jhu_to_pmd_fa.inputs.container=join('sub-'+subject, 'ses-'+session) 

rename_atlas = Node(Rename(format_string=("sub-%(subject_id)s_ses-%(session_id)s_space-%(session_id)s_desc-jhu18m_label-regfa_mask"),
                        keep_ext=True),
                        name='rename_atlas')
rename_atlas.inputs.subject_id= subject
rename_atlas.inputs.session_id= session

coreg_jhu_fa = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_jhu_fa'),
                                 remove_dest_dir=True,
                                 parameterization=False), name='coreg_jhu_fa')
coreg_jhu_fa.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
for name in flat_list:
    rename= f'{name}_rename_jhu'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-jhu_desc-regFA_{name}"),
                          keep_ext=True), name=f'{name}_rename_jhu')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
# warp files to register fa from pmd space to jhu18m atlas space
rename_jhu_affine = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdfa_to-jhufa_desc-affine_xfm"),
                        keep_ext=True),
           name='rename_jhu_affine')
rename_jhu_affine.inputs.subject_id= subject
rename_jhu_affine.inputs.session_id= session

rename_jhu_forwardwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdfa_to-jhufa_desc-forward_xfm"),
                         keep_ext=True),
  name='rename_jhu_forwardwarp')
rename_jhu_forwardwarp.inputs.subject_id= subject
rename_jhu_forwardwarp.inputs.session_id= session

rename_jhu_invwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdfa_to-jhufa_desc-inverse_xfm"),
                       keep_ext=True),
           name='rename_jhu_invwarp')
rename_jhu_invwarp.inputs.subject_id= subject
rename_jhu_invwarp.inputs.session_id= session

# %%
#connect the nodes for registration step 2
tmp = join(layout.root, 'tmp','fa', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='mask_to_patient_space_fa', base_dir=tmp)

wf.connect([(load_coreg, fa_squeez , [('fa', 'inlist')]),
            ])

# merge all coregistered files in a list except registration target 
#for count, name in enumerate(list(filter(lambda x: x != 'fa', flat_list))):
for count, name in enumerate(flat_list):
    wf.connect([(load_coreg, pmd_coregimages, [(name, f'in{count+1}')])
                ])
wf.connect([(load_fix, mask_to_pmd, [('fa', 'inputnode.fixed_image')]),
            # fa registration pmd to jhu18m, apply inv warp to altas and save atlas in pmd space 
            (fa_squeez, mask_to_pmd, [('out1', 'inputnode.moving_image')]),   
                        (load_fix, mask_to_pmd, [('mask', 'inputnode.mask')]),   
                        (mask_to_pmd, split_inv_mask, [('outputnode.inv_mask', 'inlist')]),  
                        (split_inv_mask, rename_atlas, [('out1', 'in_file')]),  
                        (rename_atlas, jhu_to_pmd_fa, [('out_file', '@atlas')]),
            # apply registration on PMD coregimages to jhu space
                        (mask_to_pmd, transforms, [('outputnode.affine_matrix', 'in2'),
                                                   ('outputnode.forward_warp_field', 'in1')]),
                        (transforms, apply_transforms_forw, [('out', 'transforms')]),
                        (pmd_coregimages, apply_transforms_forw, [('out', 'input_image')]),
                        (load_fix, apply_transforms_forw, [('fa', 'reference_image')]),  
                        (apply_transforms_forw, split_pmd_forw, [('output_image', 'inlist')]),
        ])
# save and rename coregimages in jhu space
for count, name in enumerate(flat_list):
    wf.connect([(split_pmd_forw, globals()[f'{name}_rename_jhu'], [(f'out{count+1}', 'in_file')]),
                (globals()[f'{name}_rename_jhu'], coreg_jhu_fa , [('out_file', f'anat.@{name}')]),
               ])
# save warpfiles for  registration from pmd to jhu space 
wf.connect([(mask_to_pmd, rename_jhu_affine, [('outputnode.affine_matrix', 'in_file')]),
            (rename_jhu_affine, coreg_jhu_fa , [('out_file', 'xfm.@multimod')]),
            (mask_to_pmd, rename_jhu_forwardwarp, [('outputnode.forward_warp_field', 'in_file')]),
            (rename_jhu_forwardwarp, coreg_jhu_fa , [('out_file', 'xfm.@forward')]),
            (mask_to_pmd, rename_jhu_invwarp, [('outputnode.inverse_warp_field', 'in_file')]),
            (rename_jhu_invwarp, coreg_jhu_fa , [('out_file', 'xfm.@inverse')]),
           ])

# %%
# start the registration pipeline
wf.run()

# %%
# create a dataset_description.json for derivatives 'jhu18m_to_pmd_fa'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_fa', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using fa images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'FA-based template registration'}]
                
    }))

with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_fa', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_fa files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'jhu18m_to_pmd_fa'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_fa')

except:
    print('dataset_description exists ')

# %%
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_jhu_fa', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using fa images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'FA-based template registration'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_jhu_fa', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_fa files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'jhu18m_to_pmd_fa'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_fa')

except:
    print('dataset_description exists ')

# %%
wf.write_graph(dotfilename=join(layout.root,'fa_based_template_registration_workflow.dot'), format='png', simple_form=False)
from IPython.display import Image
Image(filename=join(layout.root,'fa_based_template_registration_workflow.png'))
