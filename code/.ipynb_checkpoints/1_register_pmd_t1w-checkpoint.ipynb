# %% [markdown]
# # Hypomyelinating disorders:
# ### T1w-based registration pipeline for atlas-based quantitative magnetic resonance imaging (qMRI) assessment

# %% [markdown]
# This nipype workflow was created to analyse pediatric qMRI images of Pelizaeus Merzbacher-Disease patients
# 1. the workflow registers all imaging files on the T1-weighted (t1w) image within the session
# 2. patient to template registration was performed using T1w-images, coregistered image files get warped to the template
# 3. a brain atlas segmentation from the template will transformed to the patient session space
# 4. processed outputfiles will appear in the derivatives folder

# %%
import bids
from tqdm import tqdm
import os
from os.path import join, isfile
from nipype import Workflow
from nipype.interfaces.utility import Split, Merge
from nipype.interfaces.utility import Rename
from nipype.interfaces.io import BIDSDataGrabber, DataSink
from wmi_nipype_workflows.wmi_nipype_workflows import register_to_mni
from nipype import Node, MapNode, Workflow, IdentityInterface, Function
from nipype.interfaces.ants import N4BiasFieldCorrection
from nipype.interfaces.ants.registration import RegistrationSynQuick
from nipype.interfaces.ants.resampling import ApplyTransforms
import os
# %matplotlib notebook
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/conda/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
# set path for FSL, and ANTS package
os.environ["FSLDIR"] = "/opt/fsl/"
os.environ['ANTSPATH']='/opt/conda/bin/'

# %%
# select a patient-id and session-id for loading bids layout
subject='PMD2'
session='6m'
indexer=bids.layout.index.BIDSLayoutIndexer(validate=False, ignore=['code','tmp'])
layout = bids.BIDSLayout(os.path.dirname(os.getcwd()), derivatives=True, validate=False, indexer=indexer)
# Out:
# /opt/conda/lib/python3.9/site-packages/bids/config.py:38: FutureWarning: Setting 'extension_initial_dot' will be removed in pybids 0.16.
#   warnings.warn("Setting 'extension_initial_dot' will be removed in pybids 0.16.",

# %%
# configure inputqueries (all modalities to register) 
# file naming and file folders must follow BIDS standard
inputqueries = {
                't1w': dict(suffix='T1w', session=session, extension='nii.gz', acquisition=None, desc=None),
                'bval': dict(suffix='dwi', session=session, extension='bval' ),
                'dwi': dict(suffix='dwi', session=session, extension='nii.gz' ),
                'fa': dict(suffix='FA', session=session, extension='nii.gz', scope='derivatives', desc=None),
                't2w': dict(suffix='T2w', session=session, extension='nii.gz', acquisition=None, desc=None),
                'spgr': dict(suffix='T1w', session=session, extension='nii.gz', acquisition='SPGR'),
                'mwf': dict(suffix='mwfmap', session=session, extension='nii.gz', scope='derivatives'),
         }
optional_queries={
                'mrt': dict(suffix='mrtmap', session=session, extension='nii.gz', scope='derivatives'),
                'qt1': dict(suffix='T1map', session=session, extension='nii.gz', scope='derivatives'),
                'qt2': dict(suffix='T2map', session=session, extension='nii.gz', scope='derivatives'),
                'mt': dict(suffix='MT', session=session, extension='nii.gz', scope='derivatives', desc=None),
                'mtr': dict(suffix='MTR', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'ad': dict(suffix='AD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'rd': dict(suffix='RD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'md': dict(suffix='MD', session=session, extension='nii.gz', scope='derivatives', desc=None),
}

# define a dictionary containg the reference image as key (use same keys as in queries) for coregister session images and 
# list of maps to apply the warpfield on for the individual qMRI modality 
ref_image_matcher={'spgr': ['mwf', 'qt1','qt2','mrt'], # mcdespot registration target (spgr) and mcdespot maps (MWF, qT1...)
                   'b0': ['fa'],
                   't1w': None,
                   't2w': None,
                   'mtr':['mt']                   
}

# load template as fixed (reference)images  default jhu18m 
# change the path for the T1w, T2w and a FA image as well as the atlas segmenation (mask) for using an alternativ atlas
load_fix = Node(IdentityInterface(fields=['t1','t2','fa','mask']), name='load_fix')
load_fix.inputs.t1= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t1_ss_lps.nii.gz')
load_fix.inputs.t2= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t2ax_ss_lps.nii.gz')
load_fix.inputs.fa= join(layout.root,'code','templates','JHU_pediatric','18month', 'JHU_pediatric18_SS_fa_ss_lps.nii.gz')
load_fix.inputs.mask= join(layout.root,'code','templates','JHU_pediatric','18month','dil_ventricle_atlas18m.nii.gz')

# %%
# load files for every patient
in_files = {}
queries= inputqueries
queries.update(optional_queries)   
### STEP 1 coregistrater files within the session ####
inputnode = Node(IdentityInterface(list(queries.keys())), name='inputnode')
for key in queries.keys():
        # load input files according to dict
    in_files[key] = layout.get(**queries[key], return_type='file', subject=subject, invalid_filters='allow')
    inputnode.set_input(key, in_files[key])

# %%
# files found as specified for the inputnode
# Note only one file per inputfield should be found
print(f'found files of subject: {subject}, session: {session} for co-registration to t1w image')
inputnode.inputs
# Out:
# found files of subject: PMD2, session: 6m for co-registration to t1w image
# bval = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/dwi/sub-PMD2_ses-6m_dwi.bval']
# dwi = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/dwi/sub-PMD2_ses-6m_dwi.nii.gz']
# fa = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/DWI/sub-PMD2/ses-6m/sub-PMD2_ses-6m_FA.nii.gz']
# mrt = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD2/ses-6m/sub-PMD2_ses-6m_mrtmap.nii.gz']
# mt = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/MTR/sub-PMD2/ses-6m/sub-PMD2_ses-6m_MT.nii.gz']
# mtr = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/MTR/sub-PMD2/ses-6m/sub-PMD2_ses-6m_MTR.nii.gz']
# mwf = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD2/ses-6m/sub-PMD2_ses-6m_mwfmap.nii.gz']
# qt1 = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD2/ses-6m/sub-PMD2_ses-6m_T1map.nii.gz']
# qt2 = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/mcdespot/sub-PMD2/ses-6m/sub-PMD2_ses-6m_T2map.nii.gz']
# spgr = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/anat/sub-PMD2_ses-6m_acq-SPGR_T1w.nii.gz']
# t1w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/anat/sub-PMD2_ses-6m_T1w.nii.gz']
# t2w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/anat/sub-PMD2_ses-6m_T2w.nii.gz']

# %%
#squeeze= remove list from loaded files
for q in list(queries.keys()):
    squeezer= f'{q}_squeezer'
        
    globals()[squeezer]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeezer')
    #t1w_squeezer = Node(Split(splits=[1], squeeze=True), name='t1w_squeezer')

# %%
flat_list = []
for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:

                flat_list.append(v)
flat_list=list(set(flat_list))
flat_list
# Out:
# ['fa', 'mrt', 'qt2', 'mtr', 'qt1', 'b0', 'mwf', 'mt', 'spgr', 't2w', 't1w']

# %%
from wmi_nipype_workflows.wmi_nipype_workflows.brainextract_workflow import brain_extraction_wf
from nipype.interfaces.fsl.maths import ApplyMask
from nipype.interfaces.fsl import ImageMaths
from nipype.interfaces.fsl import BET
from nipype.interfaces.ants import N4BiasFieldCorrection
# brainextraction workflow --> robustvov get biascorrected T1w image 
brain_ex_t1 = brain_extraction_wf(report_dir=join(layout.root,'tmp','wmi_workflow_report'))
robustfov = brain_ex_t1.get_node('robustfov')
#bet = Node(BET(robust=True, mask=True, frac= 0.5), name='bet')
#bias_correction = Node(N4BiasFieldCorrection(), name="bias_correction" )

# %%
# get registration target spgrfa18 for registration of resulting mcdespot maps 
from dwi_target import get_dwi_target, get_mwf_target
mwf_target = get_mwf_target()

# %%
# generate a b0 image
b0_sink = Node(DataSink(base_directory=join(layout.root, 'derivatives', 'b0'),
                                     remove_dest_dir=True,
                                     parameterization=False),
                                     name='b0_sink')
b0_sink.inputs.container=join('sub-'+subject, 'ses-'+session)
                
# calculate b0 image for fa registration
from dti_b0 import b0_average
avg_b0 = Node(Function(input_names=['in_dwi', 'in_bval'],
                            output_names=['out_file'],
                            function=b0_average),
                         name='b0_avg')
rename_b0 = Node(Rename(format_string=("sub-{subject}_ses-{session}_space-{session}_b0"),
                                 keep_ext=True),
                          name='rename_b0')
rename_b0.inputs.subject_id= subject
rename_b0.inputs.session_id= session

# %%
coreg_sink = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_session'),
                                    remove_dest_dir=True,
                                    parameterization=False),
                            name='coreg_sink')         
coreg_sink.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
# nodes for coregister session 
for ref in list(ref_image_matcher.keys()):
    coreg= f'{ref}_coreg'
    rename_affine= f'{ref}_rename_affine'
    # nodes for coregister session 
    globals()[coreg]= Node(RegistrationSynQuick(transform_type="r"), name=f'{ref}_coreg')
    # nods for rename and save affine matrix from coregister session
    globals()[rename_affine]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-from{ref}_to_sessiont1w_xfm"),
                          keep_ext=True), name=f'{ref}_rename_affine')
    globals()[rename_affine].inputs.subject_id= subject
    globals()[rename_affine].inputs.session_id= session

# %%
# nodes for apply warp to quantitative maps
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            applyw= f'{qmrimap}_applyw'
            globals()[applyw]= Node(ApplyTransforms(), name=f'{qmrimap}_applyw')

# %%
# flatten list for ref_image_matcher.items()
flat_list = []

for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    #print(flat_list)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:
                #print('v', v)
                flat_list.append(v)
                #print(flat_list)
        
flat_list=list(set(flat_list))
flat_list
# Out:
# ['fa', 'mrt', 'qt2', 'mtr', 'qt1', 'b0', 'mwf', 'mt', 'spgr', 't2w', 't1w']

# %%
# adjust for different Image Dimension, otherwise brain mask cant be applied
from nilearn.image import resample_to_img
# create Node for resample all images to apply brainmask
def resampling(target, in_file): 
    import nibabel as nib
    from nilearn.image import resample_to_img
    from os.path import abspath, dirname, basename
    out_file = abspath('resampled_'+basename(in_file))
    resampled = resample_to_img(source_img=in_file, target_img=target)
    nib.save(resampled, out_file)
    return out_file

    
for image in flat_list:
    resample= f'{image}_resample'
    globals()[resample] = Node(Function(function=resampling,
                                       input_names=["target", "in_file"],
                                       output_names=["out_file"]),
                            name=f'{image}_resample')

# %%
## Apply the brainmask to the images which are registered within session
for image in flat_list:
    applymask= f'{image}_applymask'
    globals()[applymask] = Node(ApplyMask(), name=f'{image}_applymask')

# %%
for name in flat_list:
    rename= f'{name}_rename'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-t1w_desc-brainextracted_{name}"),
                          keep_ext=True), name=f'{name}_rename')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
#print(os.path.dirname(os.getcwd()))
#layout.get(suffix='T2w', session=session, extension='nii.gz', acquisition=None, desc=None)

# %%
tmp = join(layout.root, 'tmp', 't1w', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='coreg_pmd', base_dir=tmp)
# load files and remove list (squeeze)
for qname in list(queries.keys()):
    if qname == 'spgr':
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
                     #extract spgrfa18 from 4d file
                     (spgr_squeezer, mwf_target, [('out1', 'inputnode.in_file')]),
                  ])   
    else:
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
         #[(inputnode, globals()[f'{qname}_squeezer'], [('t1w','inlist')]),
          ])
wf.connect( 
            # connect t1w image with brain extraction workflow use robustfov image as fixed image
            [(t1w_squeezer, brain_ex_t1, [('out1', 'inputnode.in_file')]),

             
             # b0 image calcuation for regsitering FA maps...
             (bval_squeezer, avg_b0, [('out1', 'in_bval')]),
             (dwi_squeezer, avg_b0, [('out1', 'in_dwi')]),
             (avg_b0, rename_b0, [('out_file', 'in_file')]),
             (rename_b0, b0_sink, [('out_file', '@b0')]),
             
 
            ])
# step 1 register images within the session to t1w image
for ref in list(ref_image_matcher.keys()):
    wf.connect( [( robustfov, globals()[f'{ref}_coreg'], [('out_roi','fixed_image')]),  

                 
                ])
    if ref=='spgr':
        wf.connect( [(mwf_target, spgr_coreg, [('outputnode.spgr_target','moving_image')]),
                    (spgr_coreg, spgr_rename_affine, [('out_matrix', 'in_file')]),
                    (spgr_rename_affine, coreg_sink, [('out_file', f'xfm.@spgr')]),
                    ])   
    elif ref=='b0':
        wf.connect( [(avg_b0, b0_coreg, [('out_file','moving_image')]),
                    (b0_coreg, b0_rename_affine, [('out_matrix', 'in_file')]),
                    (b0_rename_affine, coreg_sink, [('out_file', f'xfm.@b0')]),
                    ])       
    else:
        wf.connect( [(globals()[f'{ref}_squeezer'], globals()[f'{ref}_coreg'], [('out1','moving_image')]),
                     (globals()[f'{ref}_coreg'], globals()[f'{ref}_rename_affine'], [('out_matrix','in_file')]),
                     (globals()[f'{ref}_rename_affine'], coreg_sink, [('out_file', f'xfm.@{ref}')]),
                ])
# apply individual warpfields to qmri maps corresponding to ref_image_matcher 
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            wf.connect( [( globals()[f'{ref}_coreg'], globals()[f'{qmrimap}_applyw'], [('out_matrix', 'transforms')]),
                         ( t1w_squeezer, globals()[f'{qmrimap}_applyw'], [('out1', 'reference_image')]),
                         ( globals()[f'{qmrimap}_squeezer'], globals()[f'{qmrimap}_applyw'], [('out1', 'input_image')]),

                        ])

for name in flat_list:                         
    if  name in list(ref_image_matcher.keys()):
       # resample ref_images
        wf.connect( [(globals()[f'{name}_coreg'], globals()[f'{name}_resample'], [('warped_image', 'in_file')]), 
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                      ])
    else: # resample all maps                     
        wf.connect( [(globals()[f'{name}_applyw'], globals()[f'{name}_resample'], [('output_image', 'in_file')]),
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                    ])
# apply brainmask to all images
for name in flat_list:  
    wf.connect( [   
                     (globals()[f'{name}_resample'],globals()[f'{name}_applymask'], [('out_file', 'in_file')]), 
                         
                          #(bet, globals()[f'{qmrimap}_applymask'], [('mask_file', 'mask_file')]),
                         (brain_ex_t1, globals()[f'{name}_applymask'], [('outputnode.mask', 'mask_file')]),
                         
                         (globals()[f'{name}_applymask'],globals()[f'{name}_rename'], [('out_file', 'in_file')]), 
                         #(globals()[f'{qmrimap}_resample'], globals()[f'{qmrimap}_rename'], [('out_file', 'in_file')]), 
                         (globals()[f'{name}_rename'], coreg_sink, [('out_file', f'anat.@{name}')]),
                ])

# %%
# run nodes for registration workkflow step 1
wf.run()
# Out:
# 240130-10:42:13,304 nipype.workflow INFO:
# 	 Workflow coreg_pmd settings: ['check', 'execution', 'logging', 'monitoring']
# 240130-10:42:13,328 nipype.workflow INFO:
# 	 Running serially.
# 240130-10:42:13,329 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/t1w_squeezer".
# 240130-10:42:13,332 nipype.workflow INFO:
# 	 [Node] Executing "t1w_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,334 nipype.workflow INFO:
# 	 [Node] Finished "t1w_squeezer", elapsed time 0.000279s.
# 240130-10:42:13,337 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.bval_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/bval_squeezer".
# 240130-10:42:13,339 nipype.workflow INFO:
# 	 [Node] Executing "bval_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,340 nipype.workflow INFO:
# 	 [Node] Finished "bval_squeezer", elapsed time 0.000268s.
# 240130-10:42:13,343 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.dwi_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/dwi_squeezer".
# 240130-10:42:13,345 nipype.workflow INFO:
# 	 [Node] Executing "dwi_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,346 nipype.workflow INFO:
# 	 [Node] Finished "dwi_squeezer", elapsed time 0.000266s.
# 240130-10:42:13,349 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/fa_squeezer".
# 240130-10:42:13,351 nipype.workflow INFO:
# 	 [Node] Executing "fa_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,353 nipype.workflow INFO:
# 	 [Node] Finished "fa_squeezer", elapsed time 0.000296s.
# 240130-10:42:13,355 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/t2w_squeezer".
# 240130-10:42:13,358 nipype.workflow INFO:
# 	 [Node] Executing "t2w_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,359 nipype.workflow INFO:
# 	 [Node] Finished "t2w_squeezer", elapsed time 0.000303s.
# 240130-10:42:13,362 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/spgr_squeezer".
# 240130-10:42:13,364 nipype.workflow INFO:
# 	 [Node] Executing "spgr_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,366 nipype.workflow INFO:
# 	 [Node] Finished "spgr_squeezer", elapsed time 0.000302s.
# 240130-10:42:13,369 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mwf_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/mwf_squeezer".
# 240130-10:42:13,372 nipype.workflow INFO:
# 	 [Node] Executing "mwf_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,375 nipype.workflow INFO:
# 	 [Node] Finished "mwf_squeezer", elapsed time 0.000873s.
# 240130-10:42:13,379 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mrt_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/mrt_squeezer".
# 240130-10:42:13,382 nipype.workflow INFO:
# 	 [Node] Executing "mrt_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,385 nipype.workflow INFO:
# 	 [Node] Finished "mrt_squeezer", elapsed time 0.000665s.
# 240130-10:42:13,389 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.qt1_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/qt1_squeezer".
# 240130-10:42:13,393 nipype.workflow INFO:
# 	 [Node] Executing "qt1_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,395 nipype.workflow INFO:
# 	 [Node] Finished "qt1_squeezer", elapsed time 0.000533s.
# 240130-10:42:13,399 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.qt2_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/qt2_squeezer".
# 240130-10:42:13,402 nipype.workflow INFO:
# 	 [Node] Executing "qt2_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,405 nipype.workflow INFO:
# 	 [Node] Finished "qt2_squeezer", elapsed time 0.000466s.
# 240130-10:42:13,408 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mt_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/mt_squeezer".
# 240130-10:42:13,411 nipype.workflow INFO:
# 	 [Node] Executing "mt_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,414 nipype.workflow INFO:
# 	 [Node] Finished "mt_squeezer", elapsed time 0.000422s.
# 240130-10:42:13,417 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.mtr_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/mtr_squeezer".
# 240130-10:42:13,420 nipype.workflow INFO:
# 	 [Node] Executing "mtr_squeezer" <nipype.interfaces.utility.base.Split>
# 240130-10:42:13,422 nipype.workflow INFO:
# 	 [Node] Finished "mtr_squeezer", elapsed time 0.000411s.
# 240130-10:42:13,425 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.n4correction" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/n4correction".
# 240130-10:42:13,429 nipype.workflow INFO:
# 	 [Node] Executing "n4correction" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240130-10:43:23,576 nipype.workflow INFO:
# 	 [Node] Finished "n4correction", elapsed time 70.142843s.
# 240130-10:43:23,580 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.subject_id_node" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/subject_id_node".
# 240130-10:43:23,583 nipype.workflow INFO:
# 	 [Node] Executing "subject_id_node" <nipype.interfaces.utility.wrappers.Function>
# 240130-10:43:23,584 nipype.workflow INFO:
# 	 [Node] Finished "subject_id_node", elapsed time 0.000442s.
# 240130-10:43:23,587 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_avg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg".
# 240130-10:43:23,590 nipype.workflow INFO:
# 	 [Node] Executing "b0_avg" <nipype.interfaces.utility.wrappers.Function>
# 240130-10:43:24,182 nipype.workflow INFO:
# 	 [Node] Finished "b0_avg", elapsed time 0.591333s.
# 240130-10:43:24,186 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_target.split_spgr" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/spgr_target/split_spgr".
# 240130-10:43:24,188 nipype.workflow INFO:
# 	 [Node] Executing "split_spgr" <nipype.interfaces.fsl.utils.Split>
# 240130-10:43:25,683 nipype.workflow INFO:
# 	 [Node] Finished "split_spgr", elapsed time 1.492964s.
# 240130-10:43:25,689 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.robustfov" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov".
# 240130-10:43:25,694 nipype.workflow INFO:
# 	 [Node] Executing "robustfov" <wmi_nipype_workflows.wmi_nipype_workflows.brainextract_workflow.RobustFOVadv>
# 240130-10:43:27,820 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:27.820154:Final FOV is:
# 240130-10:43:27,822 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:27.820154:0.000000 144.000000 0.000000 200.000000 64.000000 170.000000
# 240130-10:43:27,823 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:27.820154:
# 240130-10:43:27,978 nipype.workflow INFO:
# 	 [Node] Finished "robustfov", elapsed time 2.282877s.
# 240130-10:43:27,982 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.rename_b0" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/rename_b0".
# 240130-10:43:27,985 nipype.workflow INFO:
# 	 [Node] Executing "rename_b0" <nipype.interfaces.utility.base.Rename>
# 240130-10:43:27,987 nipype.workflow INFO:
# 	 [Node] Finished "rename_b0", elapsed time 0.000583s.
# 240130-10:43:27,989 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.spgr_target.get_target" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/spgr_target/get_target".
# 240130-10:43:27,992 nipype.workflow INFO:
# 	 [Node] Executing "get_target" <nipype.interfaces.utility.wrappers.Function>
# 240130-10:43:27,995 nipype.workflow INFO:
# 	 [Node] Finished "get_target", elapsed time 0.000667s.
# 240130-10:43:27,999 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_coreg".
# 240130-10:43:28,6 nipype.workflow INFO:
# 	 [Node] Executing "b0_coreg" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 240130-10:43:28,66 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101:
# 240130-10:43:28,68 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101:--------------------------------------------------------------------------------------
# 240130-10:43:28,69 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Mapping parameters
# 240130-10:43:28,70 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101:--------------------------------------------------------------------------------------
# 240130-10:43:28,71 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: ANTSPATH is /opt/conda/bin/
# 240130-10:43:28,71 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101:
# 240130-10:43:28,72 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Dimensionality:           3
# 240130-10:43:28,73 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Output name prefix:       transform
# 240130-10:43:28,74 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Fixed images:             /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-10:43:28,75 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Moving images:            /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg/sub-PMD2_ses-6m_dwi_avg_b0.nii.gz
# 240130-10:43:28,76 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Mask images:
# 240130-10:43:28,76 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Initial transforms:
# 240130-10:43:28,80 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Number of threads:        1
# 240130-10:43:28,80 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Spline distance:          26
# 240130-10:43:28,81 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Transform type:           r
# 240130-10:43:28,82 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: MI histogram bins:        32
# 240130-10:43:28,83 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Precision:                d
# 240130-10:43:28,83 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101: Use histogram matching    0
# 240130-10:43:28,84 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.066101:======================================================================================
# 240130-10:43:28,227 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.227408: antsRegistration call:
# 240130-10:43:28,228 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.227408:--------------------------------------------------------------------------------------
# 240130-10:43:28,230 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.230315:/opt/conda/bin//antsRegistration --verbose 1 --dimensionality 3 --float 0 --collapse-output-transforms 1 --output [transform,transformWarped.nii.gz,transformInverseWarped.nii.gz] --interpolation Linear --use-histogram-matching 0 --winsorize-image-intensities [0.005,0.995] --initial-moving-transform [/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg/sub-PMD2_ses-6m_dwi_avg_b0.nii.gz,1] --transform Rigid[0.1] --metric MI[/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz,/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg/sub-PMD2_ses-6m_dwi_avg_b0.nii.gz,1,32,Regular,0.25] --convergence [1000x500x250x0,1e-6,10] --shrink-factors 8x4x2x1 --smoothing-sigmas 3x2x1x0vox
# 240130-10:43:28,231 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.230315:--------------------------------------------------------------------------------------
# 240130-10:43:28,253 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.253503:All_Command_lines_OK
# 240130-10:43:28,254 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.253503:Using double precision for computations.
# 240130-10:43:28,472 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.472724:=============================================================================
# 240130-10:43:28,474 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.472724:The composite transform comprises the following transforms (in order):
# 240130-10:43:28,475 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.472724:  1. Center of mass alignment using fixed image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz and moving image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg/sub-PMD2_ses-6m_dwi_avg_b0.nii.gz (type = Euler3DTransform)
# 240130-10:43:28,475 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.472724:=============================================================================
# 240130-10:43:28,477 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.477688:  number of levels = 4
# 240130-10:43:28,478 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.477688:  fixed image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-10:43:28,479 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.477688:  moving image: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/b0_avg/sub-PMD2_ses-6m_dwi_avg_b0.nii.gz
# 240130-10:43:28,639 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Dimension = 3
# 240130-10:43:28,640 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Number of stages = 1
# 240130-10:43:28,641 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Use Histogram Matching false
# 240130-10:43:28,642 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Winsorize image intensities true
# 240130-10:43:28,643 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Lower quantile = 0.005
# 240130-10:43:28,643 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Upper quantile = 0.995
# 240130-10:43:28,645 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:Stage 1 State
# 240130-10:43:28,645 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:   Image metric = Mattes
# 240130-10:43:28,646 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:     Fixed image = Image (0x55d0313dbe70)
# 240130-10:43:28,647 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  RTTI typeinfo:   itk::Image<double, 3u>
# 240130-10:43:28,648 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Reference Count: 2
# 240130-10:43:28,649 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Modified Time: 1560
# 240130-10:43:28,650 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Debug: Off
# 240130-10:43:28,650 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Object Name:
# 240130-10:43:28,651 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Observers:
# 240130-10:43:28,652 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    none
# 240130-10:43:28,653 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Source: (none)
# 240130-10:43:28,654 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Source output name: (none)
# 240130-10:43:28,655 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Release Data: Off
# 240130-10:43:28,656 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Data Released: False
# 240130-10:43:28,656 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Global Release Data: Off
# 240130-10:43:28,657 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  PipelineMTime: 0
# 240130-10:43:28,658 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  UpdateMTime: 1369
# 240130-10:43:28,659 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  RealTimeStamp: 0 seconds
# 240130-10:43:28,660 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  LargestPossibleRegion:
# 240130-10:43:28,661 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Dimension: 3
# 240130-10:43:28,661 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Index: [0, 0, 0]
# 240130-10:43:28,662 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Size: [144, 200, 170]
# 240130-10:43:28,663 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  BufferedRegion:
# 240130-10:43:28,664 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Dimension: 3
# 240130-10:43:28,664 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Index: [0, 0, 0]
# 240130-10:43:28,665 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Size: [144, 200, 170]
# 240130-10:43:28,666 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  RequestedRegion:
# 240130-10:43:28,667 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Dimension: 3
# 240130-10:43:28,668 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Index: [0, 0, 0]
# 240130-10:43:28,668 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:    Size: [144, 200, 170]
# 240130-10:43:28,669 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.639085:  Spacing: [1, 1, 1]
# 240130-10:43:28,677 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Origin: [72.8494, 117.217, -106.855]
# 240130-10:43:28,677 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Direction:
# 240130-10:43:28,678 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-1 0 0
# 240130-10:43:28,679 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 -1 0
# 240130-10:43:28,679 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 0 1
# 240130-10:43:28,679 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,680 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  IndexToPointMatrix:
# 240130-10:43:28,680 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-1 0 0
# 240130-10:43:28,681 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 -1 0
# 240130-10:43:28,681 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 0 1
# 240130-10:43:28,682 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,682 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  PointToIndexMatrix:
# 240130-10:43:28,682 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-1 0 0
# 240130-10:43:28,683 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 -1 0
# 240130-10:43:28,683 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 0 1
# 240130-10:43:28,684 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,684 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Inverse Direction:
# 240130-10:43:28,685 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-1 0 0
# 240130-10:43:28,685 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 -1 0
# 240130-10:43:28,686 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0 0 1
# 240130-10:43:28,686 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,686 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  PixelContainer:
# 240130-10:43:28,687 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    ImportImageContainer (0x55d0313be360)
# 240130-10:43:28,687 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
# 240130-10:43:28,688 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Reference Count: 1
# 240130-10:43:28,688 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Modified Time: 1366
# 240130-10:43:28,689 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Debug: Off
# 240130-10:43:28,689 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Object Name:
# 240130-10:43:28,689 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Observers:
# 240130-10:43:28,690 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:        none
# 240130-10:43:28,690 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Pointer: 0x7f8073bdc010
# 240130-10:43:28,691 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Container manages memory: true
# 240130-10:43:28,691 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Size: 4896000
# 240130-10:43:28,691 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Capacity: 4896000
# 240130-10:43:28,692 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,692 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Moving image = Image (0x55d0313eced0)
# 240130-10:43:28,693 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  RTTI typeinfo:   itk::Image<double, 3u>
# 240130-10:43:28,693 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Reference Count: 2
# 240130-10:43:28,694 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Modified Time: 1561
# 240130-10:43:28,694 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Debug: Off
# 240130-10:43:28,694 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Object Name:
# 240130-10:43:28,695 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Observers:
# 240130-10:43:28,695 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    none
# 240130-10:43:28,696 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Source: (none)
# 240130-10:43:28,696 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Source output name: (none)
# 240130-10:43:28,697 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Release Data: Off
# 240130-10:43:28,697 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Data Released: False
# 240130-10:43:28,697 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Global Release Data: Off
# 240130-10:43:28,698 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  PipelineMTime: 0
# 240130-10:43:28,698 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  UpdateMTime: 1558
# 240130-10:43:28,699 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  RealTimeStamp: 0 seconds
# 240130-10:43:28,699 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  LargestPossibleRegion:
# 240130-10:43:28,699 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Dimension: 3
# 240130-10:43:28,700 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Index: [0, 0, 0]
# 240130-10:43:28,700 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Size: [104, 104, 64]
# 240130-10:43:28,701 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  BufferedRegion:
# 240130-10:43:28,701 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Dimension: 3
# 240130-10:43:28,706 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Index: [0, 0, 0]
# 240130-10:43:28,706 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Size: [104, 104, 64]
# 240130-10:43:28,707 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  RequestedRegion:
# 240130-10:43:28,707 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Dimension: 3
# 240130-10:43:28,707 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Index: [0, 0, 0]
# 240130-10:43:28,708 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    Size: [104, 104, 64]
# 240130-10:43:28,708 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Spacing: [2, 2, 2]
# 240130-10:43:28,708 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Origin: [-107.63, 108.567, -74.6999]
# 240130-10:43:28,709 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Direction:
# 240130-10:43:28,709 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.99584 0.0906285 -0.00947975
# 240130-10:43:28,709 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.0909458 -0.994994 0.0414121
# 240130-10:43:28,710 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.00567919 0.0421019 0.999097
# 240130-10:43:28,710 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,710 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  IndexToPointMatrix:
# 240130-10:43:28,711 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:1.99168 0.181257 -0.0189595
# 240130-10:43:28,711 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.181892 -1.98999 0.0828241
# 240130-10:43:28,712 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.0113584 0.0842038 1.99819
# 240130-10:43:28,712 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,712 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  PointToIndexMatrix:
# 240130-10:43:28,713 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.49792 0.0454729 0.00283959
# 240130-10:43:28,713 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.0453143 -0.497497 0.021051
# 240130-10:43:28,713 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-0.00473988 0.020706 0.499549
# 240130-10:43:28,714 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,714 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  Inverse Direction:
# 240130-10:43:28,714 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.99584 0.0909458 0.00567919
# 240130-10:43:28,715 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:0.0906285 -0.994994 0.0421019
# 240130-10:43:28,715 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:-0.00947975 0.0414121 0.999097
# 240130-10:43:28,715 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,716 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  PixelContainer:
# 240130-10:43:28,716 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:    ImportImageContainer (0x55d0313e3a90)
# 240130-10:43:28,716 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
# 240130-10:43:28,717 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Reference Count: 1
# 240130-10:43:28,717 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Modified Time: 1555
# 240130-10:43:28,717 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Debug: Off
# 240130-10:43:28,720 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Object Name:
# 240130-10:43:28,720 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Observers:
# 240130-10:43:28,721 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:        none
# 240130-10:43:28,721 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Pointer: 0x55d0313f53b0
# 240130-10:43:28,721 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Container manages memory: true
# 240130-10:43:28,722 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Size: 692224
# 240130-10:43:28,722 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:      Capacity: 692224
# 240130-10:43:28,722 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,723 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Weighting = 1
# 240130-10:43:28,723 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Sampling strategy = regular
# 240130-10:43:28,723 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Number of bins = 32
# 240130-10:43:28,724 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Radius = 4
# 240130-10:43:28,724 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Sampling percentage  = 0.25
# 240130-10:43:28,724 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:   Transform = Rigid
# 240130-10:43:28,725 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Gradient step = 0.1
# 240130-10:43:28,725 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Update field sigma (voxel space) = 0
# 240130-10:43:28,726 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Total field sigma (voxel space) = 0
# 240130-10:43:28,726 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Update field time sigma = 0
# 240130-10:43:28,726 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Total field time sigma  = 0
# 240130-10:43:28,727 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Number of time indices = 0
# 240130-10:43:28,727 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:     Number of time point samples = 0
# 240130-10:43:28,727 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:Registration using 1 total stages.
# 240130-10:43:28,728 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:
# 240130-10:43:28,728 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:Stage 0
# 240130-10:43:28,728 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  iterations = 1000x500x250x0
# 240130-10:43:28,729 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  convergence threshold = 1e-06
# 240130-10:43:28,729 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  convergence window size = 10
# 240130-10:43:28,729 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  number of levels = 4
# 240130-10:43:28,730 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.677188:  using the Mattes MI metric (number of bins = 32, weight = 1)
# 240130-10:43:28,906 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.906113:  preprocessing:  winsorizing the image intensities
# 240130-10:43:28,907 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  Shrink factors (level 1 out of 4): [8, 8, 8]
# 240130-10:43:28,908 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  Shrink factors (level 2 out of 4): [4, 4, 4]
# 240130-10:43:28,909 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  Shrink factors (level 3 out of 4): [2, 2, 2]
# 240130-10:43:28,909 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  Shrink factors (level 4 out of 4): [1, 1, 1]
# 240130-10:43:28,910 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  smoothing sigmas per level: [3, 2, 1, 0]
# 240130-10:43:28,911 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.907471:  regular sampling (percentage = 0.25)
# 240130-10:43:28,917 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.917383:
# 240130-10:43:28,918 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.917383:*** Running Euler3DTransform registration ***
# 240130-10:43:28,919 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:28.917383:
# 240130-10:43:30,82 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.082309:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-10:43:30,84 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.084074: 2DIAGNOSTIC,     1, -6.649012151302e-01, 1.797693134862e+308, 1.1712e+00, 1.1712e+00,
# 240130-10:43:30,87 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.087498: 2DIAGNOSTIC,     2, -6.687265357172e-01, 1.797693134862e+308, 1.1763e+00, 5.1661e-03,
# 240130-10:43:30,92 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.092648: 2DIAGNOSTIC,     3, -6.732475510407e-01, 1.797693134862e+308, 1.1814e+00, 5.0499e-03,
# 240130-10:43:30,98 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.098571: 2DIAGNOSTIC,     4, -6.832077861640e-01, 1.797693134862e+308, 1.1874e+00, 5.9769e-03,
# 240130-10:43:30,103 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.103905: 2DIAGNOSTIC,     5, -6.893641768274e-01, 1.797693134862e+308, 1.1927e+00, 5.3060e-03,
# 240130-10:43:30,109 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.109143: 2DIAGNOSTIC,     6, -6.972958060628e-01, 1.797693134862e+308, 1.1979e+00, 5.1930e-03,
# 240130-10:43:30,114 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.114328: 2DIAGNOSTIC,     7, -7.236625256028e-01, 1.797693134862e+308, 1.2031e+00, 5.1999e-03,
# 240130-10:43:30,119 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.119902: 2DIAGNOSTIC,     8, -7.624288762461e-01, 1.797693134862e+308, 1.2086e+00, 5.5230e-03,
# 240130-10:43:30,127 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.127520: 2DIAGNOSTIC,     9, -8.591115071752e-01, 1.797693134862e+308, 1.2162e+00, 7.6210e-03,
# 240130-10:43:30,135 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.135050: 2DIAGNOSTIC,    10, -8.998096278859e-01, 1.879197483493e-02, 1.2236e+00, 7.4289e-03,
# 240130-10:43:30,141 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.141131: 2DIAGNOSTIC,    11, -9.109457187467e-01, 2.078937323991e-02, 1.2298e+00, 6.1431e-03,
# 240130-10:43:30,147 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.147358: 2DIAGNOSTIC,    12, -9.148976013567e-01, 2.082874061245e-02, 1.2359e+00, 6.1238e-03,
# 240130-10:43:30,152 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.152482: 2DIAGNOSTIC,    13, -9.150811308465e-01, 1.912708660567e-02, 1.2411e+00, 5.1901e-03,
# 240130-10:43:30,158 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.158731: 2DIAGNOSTIC,    14, -9.159847439262e-01, 1.623921983588e-02, 1.2473e+00, 6.1951e-03,
# 240130-10:43:30,164 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.164869: 2DIAGNOSTIC,    15, -9.154660938720e-01, 1.245765721882e-02, 1.2534e+00, 6.1488e-03,
# 240130-10:43:30,171 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.171173: 2DIAGNOSTIC,    16, -9.168515349801e-01, 8.312516548094e-03, 1.2597e+00, 6.2091e-03,
# 240130-10:43:30,179 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.179435: 2DIAGNOSTIC,    17, -9.178008662716e-01, 4.539657737271e-03, 1.2680e+00, 8.3020e-03,
# 240130-10:43:30,184 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.184703: 2DIAGNOSTIC,    18, -9.190894328912e-01, 1.559178243915e-03, 1.2731e+00, 5.1789e-03,
# 240130-10:43:30,189 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.189830: 2DIAGNOSTIC,    19, -9.241023195961e-01, 6.258062660526e-04, 1.2783e+00, 5.1830e-03,
# 240130-10:43:30,195 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.195045: 2DIAGNOSTIC,    20, -9.250787500203e-01, 4.508164431882e-04, 1.2835e+00, 5.1789e-03,
# 240130-10:43:30,201 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.201115: 2DIAGNOSTIC,    21, -9.256355695950e-01, 4.424453040924e-04, 1.2896e+00, 6.0790e-03,
# 240130-10:43:30,206 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.206262: 2DIAGNOSTIC,    22, -9.276959134685e-01, 4.878058735398e-04, 1.2946e+00, 5.0681e-03,
# 240130-10:43:30,212 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.212335: 2DIAGNOSTIC,    23, -9.279249734097e-01, 4.882805040627e-04, 1.3007e+00, 6.0561e-03,
# 240130-10:43:30,218 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.218351: 2DIAGNOSTIC,    24, -9.283102636795e-01, 4.611439555560e-04, 1.3068e+00, 6.0492e-03,
# 240130-10:43:30,224 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.224302: 2DIAGNOSTIC,    25, -9.271589816418e-01, 3.707063022001e-04, 1.3127e+00, 5.9400e-03,
# 240130-10:43:30,229 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.229517: 2DIAGNOSTIC,    26, -9.290103772747e-01, 2.961050705086e-04, 1.3179e+00, 5.1980e-03,
# 240130-10:43:30,235 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.235460: 2DIAGNOSTIC,    27, -9.294002061257e-01, 2.156878577504e-04, 1.3238e+00, 5.9528e-03,
# 240130-10:43:30,241 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.241538: 2DIAGNOSTIC,    28, -9.297078537611e-01, 1.386188206890e-04, 1.3299e+00, 6.0620e-03,
# 240130-10:43:30,248 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.248525: 2DIAGNOSTIC,    29, -9.296201597180e-01, 1.111116189114e-04, 1.3368e+00, 6.9041e-03,
# 240130-10:43:30,253 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.253488: 2DIAGNOSTIC,    30, -9.296447696276e-01, 8.665783512588e-05, 1.3418e+00, 4.9989e-03,
# 240130-10:43:30,261 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.261390: 2DIAGNOSTIC,    31, -9.295515577529e-01, 5.996661428401e-05, 1.3497e+00, 7.8759e-03,
# 240130-10:43:30,267 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.267383: 2DIAGNOSTIC,    32, -9.297140393020e-01, 5.201448725296e-05, 1.3557e+00, 6.0041e-03,
# 240130-10:43:30,272 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.272647: 2DIAGNOSTIC,    33, -9.297452949499e-01, 4.228449285674e-05, 1.3609e+00, 5.1692e-03,
# 240130-10:43:30,278 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:30.278727: 2DIAGNOSTIC,    34, -9.282251626286e-01, 1.892065450938e-05, 1.3670e+00, 6.1331e-03,
# 240130-10:43:31,2 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.002066:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-10:43:31,3 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.002066: 2DIAGNOSTIC,     1, -7.186304996300e-01, 1.797693134862e+308, 2.0903e+00, 7.2332e-01,
# 240130-10:43:31,57 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.057694: 2DIAGNOSTIC,     2, -7.195370389721e-01, 1.797693134862e+308, 2.1459e+00, 5.5590e-02,
# 240130-10:43:31,113 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.113000: 2DIAGNOSTIC,     3, -7.206934139293e-01, 1.797693134862e+308, 2.2011e+00, 5.5204e-02,
# 240130-10:43:31,167 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.167618: 2DIAGNOSTIC,     4, -7.229169826916e-01, 1.797693134862e+308, 2.2558e+00, 5.4663e-02,
# 240130-10:43:31,222 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.222267: 2DIAGNOSTIC,     5, -7.239759392310e-01, 1.797693134862e+308, 2.3103e+00, 5.4578e-02,
# 240130-10:43:31,278 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.278538: 2DIAGNOSTIC,     6, -7.253285981230e-01, 1.797693134862e+308, 2.3666e+00, 5.6259e-02,
# 240130-10:43:31,331 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.331514: 2DIAGNOSTIC,     7, -7.268380111735e-01, 1.797693134862e+308, 2.4196e+00, 5.2953e-02,
# 240130-10:43:31,411 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.411124: 2DIAGNOSTIC,     8, -7.308003509903e-01, 1.797693134862e+308, 2.4991e+00, 7.9584e-02,
# 240130-10:43:31,470 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.470855: 2DIAGNOSTIC,     9, -7.303937442512e-01, 1.797693134862e+308, 2.5589e+00, 5.9711e-02,
# 240130-10:43:31,527 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.527469: 2DIAGNOSTIC,    10, -7.304189170308e-01, 1.195910970255e-03, 2.6155e+00, 5.6596e-02,
# 240130-10:43:31,585 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.585118: 2DIAGNOSTIC,    11, -7.304049751933e-01, 1.001869070510e-03, 2.6731e+00, 5.7633e-02,
# 240130-10:43:31,631 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.631827: 2DIAGNOSTIC,    12, -7.303501243181e-01, 7.773243448365e-04, 2.7198e+00, 4.6679e-02,
# 240130-10:43:31,702 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.702557: 2DIAGNOSTIC,    13, -7.302811076707e-01, 5.473968949112e-04, 2.7904e+00, 7.0678e-02,
# 240130-10:43:31,761 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.761542: 2DIAGNOSTIC,    14, -7.300737894190e-01, 3.574587093368e-04, 2.8494e+00, 5.8993e-02,
# 240130-10:43:31,809 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.809649: 2DIAGNOSTIC,    15, -7.300044738096e-01, 1.876396899099e-04, 2.8975e+00, 4.8088e-02,
# 240130-10:43:31,868 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:31.868037: 2DIAGNOSTIC,    16, -7.299979913811e-01, 5.494323533980e-05, 2.9559e+00, 5.8375e-02,
# 240130-10:43:32,621 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:32.621661:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-10:43:32,623 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:32.621661: 2DIAGNOSTIC,     1, -6.229349890404e-01, 1.797693134862e+308, 3.7095e+00, 7.5362e-01,
# 240130-10:43:32,939 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:32.939499: 2DIAGNOSTIC,     2, -6.238150343617e-01, 1.797693134862e+308, 4.0273e+00, 3.1780e-01,
# 240130-10:43:33,254 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:33.254289: 2DIAGNOSTIC,     3, -6.249560564711e-01, 1.797693134862e+308, 4.3421e+00, 3.1477e-01,
# 240130-10:43:33,566 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:33.566741: 2DIAGNOSTIC,     4, -6.262101626386e-01, 1.797693134862e+308, 4.6545e+00, 3.1241e-01,
# 240130-10:43:33,881 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:33.881097: 2DIAGNOSTIC,     5, -6.275668407697e-01, 1.797693134862e+308, 4.9689e+00, 3.1435e-01,
# 240130-10:43:34,199 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:34.199111: 2DIAGNOSTIC,     6, -6.290908109789e-01, 1.797693134862e+308, 5.2868e+00, 3.1797e-01,
# 240130-10:43:34,517 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:34.517541: 2DIAGNOSTIC,     7, -6.301648240207e-01, 1.797693134862e+308, 5.6052e+00, 3.1841e-01,
# 240130-10:43:35,250 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:35.250304: 2DIAGNOSTIC,     8, -6.318064449581e-01, 1.797693134862e+308, 6.3380e+00, 7.3273e-01,
# 240130-10:43:35,633 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:35.633108: 2DIAGNOSTIC,     9, -6.320000251303e-01, 1.797693134862e+308, 6.7208e+00, 3.8279e-01,
# 240130-10:43:36,20 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:36.020085: 2DIAGNOSTIC,    10, -6.319864106891e-01, 1.048960241604e-03, 7.1077e+00, 3.8694e-01,
# 240130-10:43:36,475 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:36.475810: 2DIAGNOSTIC,    11, -6.319790475783e-01, 8.468940846767e-04, 7.5634e+00, 4.5571e-01,
# 240130-10:43:36,867 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:36.867829: 2DIAGNOSTIC,    12, -6.319829602412e-01, 6.355008672644e-04, 7.9554e+00, 3.9198e-01,
# 240130-10:43:37,253 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:37.253445: 2DIAGNOSTIC,    13, -6.319802607437e-01, 4.382769083442e-04, 8.3410e+00, 3.8560e-01,
# 240130-10:43:37,639 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:37.639601: 2DIAGNOSTIC,    14, -6.319949236664e-01, 2.703194513761e-04, 8.7272e+00, 3.8620e-01,
# 240130-10:43:37,966 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:37.966753: 2DIAGNOSTIC,    15, -6.319377009481e-01, 1.393630452840e-04, 9.0543e+00, 3.2706e-01,
# 240130-10:43:38,349 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:38.349654: 2DIAGNOSTIC,    16, -6.319582673032e-01, 5.567252237780e-05, 9.4371e+00, 3.8286e-01,
# 240130-10:43:38,739 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:38.739379: 2DIAGNOSTIC,    17, -6.319943391208e-01, 5.174842930937e-06, 9.8268e+00, 3.8970e-01,
# 240130-10:43:41,318 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.318730:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-10:43:41,320 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.318730: 2DIAGNOSTIC,     1, -5.598080966933e-01, 1.797693134862e+308, 1.2406e+01, 2.5793e+00,
# 240130-10:43:41,321 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.318730:  Elapsed time (stage 0): 1.2672e+01
# 240130-10:43:41,321 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.318730:
# 240130-10:43:41,324 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.324250:
# 240130-10:43:41,325 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:41.324250:Total elapsed time: 1.2685e+01
# 240130-10:43:42,908 nipype.workflow INFO:
# 	 [Node] Finished "b0_coreg", elapsed time 14.897066s.
# 240130-10:43:42,913 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/t1w_coreg".
# 240130-10:43:42,922 nipype.workflow INFO:
# 	 [Node] Executing "t1w_coreg" <nipype.interfaces.ants.registration.RegistrationSynQuick>
# 240130-10:43:42,979 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573:
# 240130-10:43:42,982 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573:--------------------------------------------------------------------------------------
# 240130-10:43:42,983 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Mapping parameters
# 240130-10:43:42,984 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573:--------------------------------------------------------------------------------------
# 240130-10:43:42,984 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: ANTSPATH is /opt/conda/bin/
# 240130-10:43:42,985 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573:
# 240130-10:43:42,986 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Dimensionality:           3
# 240130-10:43:42,987 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Output name prefix:       transform
# 240130-10:43:42,988 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Fixed images:             /home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/t1w/sub-PMD2/ses-6m/coreg_pmd/brain_extraction/robustfov/spgr_n4corrected_ROI.nii.gz
# 240130-10:43:42,990 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Moving images:            /home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD2/ses-6m/anat/sub-PMD2_ses-6m_T1w.nii.gz
# 240130-10:43:42,991 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Mask images:
# 240130-10:43:42,992 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Initial transforms:
# 240130-10:43:42,993 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Number of threads:        1
# 240130-10:43:42,994 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Spline distance:          26
# 240130-10:43:42,995 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Transform type:           r
# 240130-10:43:42,995 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: MI histogram bins:        32
# 240130-10:43:42,996 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Precision:                d
# 240130-10:43:42,997 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573: Use histogram matching    0
# 240130-10:43:42,998 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:42.979573:======================================================================================
# 240130-10:43:43,127 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.127802: antsRegistration call:
# 240130-10:43:43,129 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.129342:--------------------------------------------------------------------------------------
# 240130-10:43:43,130 nipype.interface INFO:
# ...
# 240130-10:43:43,800 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Modified Time: 1557
# 240130-10:43:43,800 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Debug: Off
# 240130-10:43:43,801 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Object Name:
# 240130-10:43:43,801 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Observers:
# 240130-10:43:43,801 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    none
# 240130-10:43:43,802 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Source: (none)
# 240130-10:43:43,803 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Source output name: (none)
# 240130-10:43:43,803 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Release Data: Off
# 240130-10:43:43,803 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Data Released: False
# 240130-10:43:43,804 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Global Release Data: Off
# 240130-10:43:43,804 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  PipelineMTime: 0
# 240130-10:43:43,805 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  UpdateMTime: 1554
# 240130-10:43:43,805 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  RealTimeStamp: 0 seconds
# 240130-10:43:43,805 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  LargestPossibleRegion:
# 240130-10:43:43,806 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Dimension: 3
# 240130-10:43:43,806 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Index: [0, 0, 0]
# 240130-10:43:43,806 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Size: [144, 200, 256]
# 240130-10:43:43,807 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  BufferedRegion:
# 240130-10:43:43,808 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Dimension: 3
# 240130-10:43:43,808 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Index: [0, 0, 0]
# 240130-10:43:43,809 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Size: [144, 200, 256]
# 240130-10:43:43,810 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  RequestedRegion:
# 240130-10:43:43,811 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Dimension: 3
# 240130-10:43:43,812 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Index: [0, 0, 0]
# 240130-10:43:43,813 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    Size: [144, 200, 256]
# 240130-10:43:43,814 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Spacing: [1, 1, 1]
# 240130-10:43:43,814 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Origin: [72.8494, 117.217, -170.855]
# 240130-10:43:43,815 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Direction:
# 240130-10:43:43,816 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:-1 0 0
# 240130-10:43:43,817 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 -1 0
# 240130-10:43:43,818 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 0 1
# 240130-10:43:43,818 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,819 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  IndexToPointMatrix:
# 240130-10:43:43,820 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:-1 0 0
# 240130-10:43:43,821 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 -1 0
# 240130-10:43:43,822 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 0 1
# 240130-10:43:43,823 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,823 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  PointToIndexMatrix:
# 240130-10:43:43,824 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:-1 0 0
# 240130-10:43:43,825 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 -1 0
# 240130-10:43:43,825 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 0 1
# 240130-10:43:43,826 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,827 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  Inverse Direction:
# 240130-10:43:43,827 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:-1 0 0
# 240130-10:43:43,828 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 -1 0
# 240130-10:43:43,829 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:0 0 1
# 240130-10:43:43,829 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,830 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  PixelContainer:
# 240130-10:43:43,831 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:    ImportImageContainer (0x55e274ffcdd0)
# 240130-10:43:43,831 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      RTTI typeinfo:   itk::ImportImageContainer<unsigned long, double>
# 240130-10:43:43,832 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Reference Count: 1
# 240130-10:43:43,832 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Modified Time: 1551
# 240130-10:43:43,833 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Debug: Off
# 240130-10:43:43,834 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Object Name:
# 240130-10:43:43,834 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Observers:
# 240130-10:43:43,835 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:        none
# 240130-10:43:43,835 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Pointer: 0x7fd7a7eb5010
# 240130-10:43:43,836 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Container manages memory: true
# 240130-10:43:43,837 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Size: 7372800
# 240130-10:43:43,837 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:      Capacity: 7372800
# 240130-10:43:43,838 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,838 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Weighting = 1
# 240130-10:43:43,839 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Sampling strategy = regular
# 240130-10:43:43,839 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Number of bins = 32
# 240130-10:43:43,840 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Radius = 4
# 240130-10:43:43,840 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Sampling percentage  = 0.25
# 240130-10:43:43,841 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:   Transform = Rigid
# 240130-10:43:43,841 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Gradient step = 0.1
# 240130-10:43:43,842 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Update field sigma (voxel space) = 0
# 240130-10:43:43,842 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Total field sigma (voxel space) = 0
# 240130-10:43:43,843 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Update field time sigma = 0
# 240130-10:43:43,843 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Total field time sigma  = 0
# 240130-10:43:43,844 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Number of time indices = 0
# 240130-10:43:43,844 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:     Number of time point samples = 0
# 240130-10:43:43,845 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:Registration using 1 total stages.
# 240130-10:43:43,845 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:
# 240130-10:43:43,846 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:Stage 0
# 240130-10:43:43,846 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  iterations = 1000x500x250x0
# 240130-10:43:43,847 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  convergence threshold = 1e-06
# 240130-10:43:43,847 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  convergence window size = 10
# 240130-10:43:43,848 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  number of levels = 4
# 240130-10:43:43,848 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:43.786217:  using the Mattes MI metric (number of bins = 32, weight = 1)
# 240130-10:43:44,252 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  preprocessing:  winsorizing the image intensities
# 240130-10:43:44,253 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  Shrink factors (level 1 out of 4): [8, 8, 8]
# 240130-10:43:44,254 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  Shrink factors (level 2 out of 4): [4, 4, 4]
# 240130-10:43:44,255 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  Shrink factors (level 3 out of 4): [2, 2, 2]
# 240130-10:43:44,256 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  Shrink factors (level 4 out of 4): [1, 1, 1]
# 240130-10:43:44,257 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  smoothing sigmas per level: [3, 2, 1, 0]
# 240130-10:43:44,258 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.252569:  regular sampling (percentage = 0.25)
# 240130-10:43:44,262 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.262805:
# 240130-10:43:44,263 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.262805:*** Running Euler3DTransform registration ***
# 240130-10:43:44,264 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:44.262805:
# 240130-10:43:46,697 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.697312:DIAGNOSTIC,Iteration,metricValue,convergenceValue,ITERATION_TIME_INDEX,SINCE_LAST
# 240130-10:43:46,698 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.697312: 2DIAGNOSTIC,     1, -7.819384643894e-01, 1.797693134862e+308, 2.4408e+00, 2.4408e+00,
# 240130-10:43:46,705 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.705763: 2DIAGNOSTIC,     2, -7.863687186842e-01, 1.797693134862e+308, 2.4492e+00, 8.4741e-03,
# 240130-10:43:46,714 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.714262: 2DIAGNOSTIC,     3, -7.947303087253e-01, 1.797693134862e+308, 2.4576e+00, 8.3869e-03,
# 240130-10:43:46,722 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.722926: 2DIAGNOSTIC,     4, -8.120741908303e-01, 1.797693134862e+308, 2.4663e+00, 8.7059e-03,
# 240130-10:43:46,729 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.729924: 2DIAGNOSTIC,     5, -8.486205551067e-01, 1.797693134862e+308, 2.4732e+00, 6.8960e-03,
# 240130-10:43:46,737 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.737183: 2DIAGNOSTIC,     6, -9.381038428343e-01, 1.797693134862e+308, 2.4805e+00, 7.3080e-03,
# 240130-10:43:46,748 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.748140: 2DIAGNOSTIC,     7, -1.214605973916e+00, 1.797693134862e+308, 2.4914e+00, 1.0842e-02,
# 240130-10:43:46,773 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.773905: 2DIAGNOSTIC,     8, -1.370204312646e+00, 1.797693134862e+308, 2.5171e+00, 2.5732e-02,
# 240130-10:43:46,780 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.780250: 2DIAGNOSTIC,     9, -1.370203675331e+00, 1.797693134862e+308, 2.5235e+00, 6.3992e-03,
# 240130-10:43:46,787 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.786931: 2DIAGNOSTIC,    10, -1.370204535057e+00, 4.711069246487e-02, 2.5301e+00, 6.5751e-03,
# 240130-10:43:46,793 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.793239: 2DIAGNOSTIC,    11, -1.370205988625e+00, 4.309879501296e-02, 2.5364e+00, 6.3601e-03,
# 240130-10:43:46,799 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.799680: 2DIAGNOSTIC,    12, -1.370208445577e+00, 3.614600863136e-02, 2.5428e+00, 6.3422e-03,
# 240130-10:43:46,806 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.805974: 2DIAGNOSTIC,    13, -1.370212597366e+00, 2.743824385004e-02, 2.5491e+00, 6.3410e-03,
# 240130-10:43:46,812 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.812298: 2DIAGNOSTIC,    14, -1.370219609762e+00, 1.817752174833e-02, 2.5553e+00, 6.2258e-03,
# 240130-10:43:46,818 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.818589: 2DIAGNOSTIC,    15, -1.370231436274e+00, 9.423060066475e-03, 2.5617e+00, 6.3410e-03,
# 240130-10:43:46,825 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.825013: 2DIAGNOSTIC,    16, -1.370251366492e+00, 2.393009835602e-03, 2.5680e+00, 6.3269e-03,
# 240130-10:43:46,831 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.831509: 2DIAGNOSTIC,    17, -1.370284883048e+00, 4.310963448717e-06, 2.5745e+00, 6.5379e-03,
# 240130-10:43:46,837 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.837934: 2DIAGNOSTIC,    18, -1.370341026818e+00, 5.412328268298e-06, 2.5809e+00, 6.3388e-03,
# 240130-10:43:46,844 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.844378: 2DIAGNOSTIC,    19, -1.370434412378e+00, 7.223853826122e-06, 2.5874e+00, 6.4981e-03,
# 240130-10:43:46,850 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.850888: 2DIAGNOSTIC,    20, -1.370587222111e+00, 1.014024274755e-05, 2.5938e+00, 6.4211e-03,
# 240130-10:43:46,857 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.857382: 2DIAGNOSTIC,    21, -1.370833189486e+00, 1.471306900504e-05, 2.6004e+00, 6.5429e-03,
# 240130-10:43:46,863 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.863646: 2DIAGNOSTIC,    22, -1.371214766034e+00, 2.164721411287e-05, 2.6065e+00, 6.1700e-03,
# 240130-10:43:46,869 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.869809: 2DIAGNOSTIC,    23, -1.371777269953e+00, 3.170519389046e-05, 2.6127e+00, 6.2201e-03,
# 240130-10:43:46,876 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.876111: 2DIAGNOSTIC,    24, -1.372759189573e+00, 4.745774457134e-05, 2.6190e+00, 6.2139e-03,
# 240130-10:43:46,882 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.882308: 2DIAGNOSTIC,    25, -1.373600244662e+00, 6.519896077545e-05, 2.6251e+00, 6.1839e-03,
# 240130-10:43:46,888 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.888460: 2DIAGNOSTIC,    26, -1.374310401473e+00, 8.182145910469e-05, 2.6313e+00, 6.1989e-03,
# 240130-10:43:46,894 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.894667: 2DIAGNOSTIC,    27, -1.374683708771e+00, 9.296150178827e-05, 2.6375e+00, 6.1150e-03,
# 240130-10:43:46,901 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.900952: 2DIAGNOSTIC,    28, -1.374845695872e+00, 9.638566189354e-05, 2.6437e+00, 6.2611e-03,
# 240130-10:43:46,909 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.909755: 2DIAGNOSTIC,    29, -1.375059850934e+00, 9.295732192420e-05, 2.6525e+00, 8.7910e-03,
# 240130-10:43:46,917 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.917145: 2DIAGNOSTIC,    30, -1.375191745240e+00, 8.318589432972e-05, 2.6599e+00, 7.4370e-03,
# 240130-10:43:46,924 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.924614: 2DIAGNOSTIC,    31, -1.375212445388e+00, 6.827534555241e-05, 2.6673e+00, 7.3879e-03,
# 240130-10:43:46,933 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.933279: 2DIAGNOSTIC,    32, -1.375218103580e+00, 5.078185785935e-05, 2.6760e+00, 8.7190e-03,
# 240130-10:43:46,940 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.940549: 2DIAGNOSTIC,    33, -1.375219917147e+00, 3.350658762326e-05, 2.6832e+00, 7.1781e-03,
# 240130-10:43:46,954 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.954450: 2DIAGNOSTIC,    34, -1.375220646513e+00, 2.062643391850e-05, 2.6971e+00, 1.3876e-02,
# 240130-10:43:46,960 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.960506: 2DIAGNOSTIC,    35, -1.375220647567e+00, 1.193720040128e-05, 2.7031e+00, 6.0461e-03,
# 240130-10:43:46,966 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.966667: 2DIAGNOSTIC,    36, -1.375220652803e+00, 7.080566463896e-06, 2.7093e+00, 6.1429e-03,
# 240130-10:43:46,973 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:46.973788: 2DIAGNOSTIC,    37, -1.375220657915e+00, 4.164155064192e-06, 2.7164e+00, 7.1058e-03,
# 240130-10:43:47,0 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:47.000019: 2DIAGNOSTIC,    38, -1.375220661678e+00, 2.024327404846e-06, 2.7426e+00, 2.6200e-02,
# 240130-10:43:47,15 nipype.interface INFO:
# 	 stdout 2024-01-30T10:43:47.015532: 2DIAGNOSTIC,    39, -1.375220661678e+00, 1.090017210034e-06, 2.7581e+00, 1.5484e-02,

# %%
# create a dataset_description.json for derivatives 'coreg_session'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_session', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
        'Name': 'register session files on t1w image',
        'BIDSVersion': '1.4.0',
        'DatasetType': 'derivative',
        'GeneratedBy': [{'caroline.koehler@ukdd.de': 'co-register session images to T1-weighted image of the session'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_session', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_session Workflow')
# update layout otherwise coreg_session files are not found)

try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'coreg_session'))
    print ('writing dataset_description for derivatives coreg_session')

except:
    print('dataset_description exists ')

# %%
# visualize register session workflow
wf.write_graph(dotfilename=join(layout.root,'register_session_workflow.dot'), format='png', simple_form=False)
from IPython.display import Image
Image(filename=join(layout.root,'register_session_workflow.png'))

# %%
print('warp atlas in PMD space')
### STEP2: warp the jhu18m atlas in pmd patient space ###
print('reload bids layout')
layout2 = bids.BIDSLayout(layout.root, derivatives=True, validate=False, ignore=['code','tmp', 'tmp_t1w','tmp_fa','tmp_multimod'])

# %%
flat_list

# %%
load_coreg = Node(IdentityInterface(flat_list), name='inputnode2')
for name in flat_list:
    in_files= layout2.get(suffix=name, subject=subject, session=session,acquisition=None, scope='derivatives', desc='brainextracted', extension='nii.gz')
    load_coreg.set_input(name, in_files)

# %%
# shows all found coregistered and brainextracted images of the subject and session
print(f'list of files found for registration step 2 of subject:{subject}' )
load_coreg.inputs

# %%
# create multiple nodes squeeze= remove list from loaded files
for q in flat_list:
    squeez= f'{q}_squeez'
    globals()[squeez]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeez')

# %%
# merge files to list
merge_inputs=len(flat_list)# dynamic number of connections in for merge node
pmd_coregimages=Node(Merge(merge_inputs), name='pmd_coregimages') # make a list of images to use Mapnodes

# %%
# apply inverse warp field on jhu atlas/ mask
# this workflow register the moving image to a template (reference image) and apply an inverse transform to the atlas segmentation
# this warps the altas segmentation in the patient session space 
# Additionally, pmd_coreg_images get warped to jhu template
from wmi_nipype_workflows.wmi_nipype_workflows.register_to_mni import mask_to_patient_space
mask_to_pmd = mask_to_patient_space()

# %%
# split inv_mask because it is a list (mapnode)
split_inv_mask= Node(Split(), name= 'split_inv_mask')
split_inv_mask.inputs.splits= [1]
split_inv_mask.inputs.squeeze= True

# %%
# apply transforms on pmd_coregimages
# all coregistered files are also moved to template space fascilitating patient comparison
from nipype.interfaces.ants import ApplyTransforms, RegistrationSynQuick
apply_transforms_forw= MapNode(ApplyTransforms(), name = 'apply_transforms_forw', iterfield = ['input_image'])
transforms = Node(Merge(2), name='transforms')
split_pmd_forw = Node(Split(), name= 'split_pmd_forw')
split_pmd_forw.inputs.splits= [1]*merge_inputs
split_pmd_forw.inputs.squeeze= True

# %%
# rename and save jhu18m atlas/mask in pmd space
jhu_to_pmd_t1w = Node(DataSink(base_directory=join(layout.root,'derivatives', 'jhu18m_to_pmd_t1w'),
                           remove_dest_dir=True,
                            parameterization=False), name='jhu_to_pmd_t1w')
jhu_to_pmd_t1w.inputs.container=join('sub-'+subject, 'ses-'+session) 



rename_atlas = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-{session}_desc-jhu18m_label-regT1w_mask"),
                        keep_ext=True),
                        name='rename_atlas')
rename_atlas.inputs.subject_id= subject
rename_atlas.inputs.session_id= session

coreg_jhu_t1w = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_jhu_t1w'),
                                 remove_dest_dir=True,
                                 parameterization=False), name='coreg_jhu_t1w')
coreg_jhu_t1w.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
for name in flat_list:
    rename= f'{name}_rename_jhu'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-jhu_desc-regT1w_{name}"),
                          keep_ext=True), name=f'{name}_rename_jhu')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
# warp files to register fa from pmd space to jhu18m atlas space
rename_jhu_affine = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdt1w_to-jhut1w_desc-affine_xfm"),
                        keep_ext=True),
           name='rename_jhu_affine')
rename_jhu_affine.inputs.subject_id= subject
rename_jhu_affine.inputs.session_id= session

rename_jhu_forwardwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdt1w_to-jhut1w_desc-forward_xfm"),
                         keep_ext=True),
  name='rename_jhu_forwardwarp')
rename_jhu_forwardwarp.inputs.subject_id= subject
rename_jhu_forwardwarp.inputs.session_id= session

rename_jhu_invwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdt1w_to-jhut1w_desc-inverse_xfm"),
                       keep_ext=True),
           name='rename_jhu_invwarp')
rename_jhu_invwarp.inputs.subject_id= subject
rename_jhu_invwarp.inputs.session_id= session

# %%
#connect the nodes for registration step 2
tmp = join(layout.root, 'tmp','t1w', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='mask_to_patient_space_t1w', base_dir=tmp)

wf.connect([(load_coreg, t1w_squeez , [('t1w', 'inlist')]),
            ])

# merge all coregistered files in a list except registration target 

for count, name in enumerate(flat_list):
    wf.connect([(load_coreg, pmd_coregimages, [(name, f'in{count+1}')])
                ])
    
wf.connect([(load_fix, mask_to_pmd, [('t1', 'inputnode.fixed_image')]),
            # t1w registration pmd to jhu18m, apply inv warp to altas and save atlas in pmd space 
            (t1w_squeez, mask_to_pmd, [('out1', 'inputnode.moving_image')]),   
                        (load_fix, mask_to_pmd, [('mask', 'inputnode.mask')]),   
                        (mask_to_pmd, split_inv_mask, [('outputnode.inv_mask', 'inlist')]),  
                        (split_inv_mask, rename_atlas, [('out1', 'in_file')]),  
                        (rename_atlas, jhu_to_pmd_t1w, [('out_file', '@atlas')]),
            # apply registration on PMD coregimages to jhu space
                        (mask_to_pmd, transforms, [('outputnode.affine_matrix', 'in2'),
                                                   ('outputnode.forward_warp_field', 'in1')]),
                        (transforms, apply_transforms_forw, [('out', 'transforms')]),
                        (pmd_coregimages, apply_transforms_forw, [('out', 'input_image')]),
                        (load_fix, apply_transforms_forw, [('t1', 'reference_image')]),  
                        (apply_transforms_forw, split_pmd_forw, [('output_image', 'inlist')]),
        ])
# save and rename coregimages in jhu space
for count, name in enumerate(flat_list):
    wf.connect([(split_pmd_forw, globals()[f'{name}_rename_jhu'], [(f'out{count+1}', 'in_file')]),
                (globals()[f'{name}_rename_jhu'], coreg_jhu_t1w , [('out_file', f'anat.@{name}')]),
               ])
# save warpfiles for  registration from pmd to jhu space 
wf.connect([(mask_to_pmd, rename_jhu_affine, [('outputnode.affine_matrix', 'in_file')]),
            (rename_jhu_affine, coreg_jhu_t1w , [('out_file', 'xfm.@multimod')]),
            (mask_to_pmd, rename_jhu_forwardwarp, [('outputnode.forward_warp_field', 'in_file')]),
            (rename_jhu_forwardwarp, coreg_jhu_t1w , [('out_file', 'xfm.@forward')]),
            (mask_to_pmd, rename_jhu_invwarp, [('outputnode.inverse_warp_field', 'in_file')]),
            (rename_jhu_invwarp, coreg_jhu_t1w , [('out_file', 'xfm.@inverse')]),
           ])

# %%
# start the registration pipeline
wf.run()

# %%
# create a dataset_description.json for derivatives 'jhu18m_to_pmd_t1w'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_t1w', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using t1w images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'FA-based template registration'}]
    }))

with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_t1w', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_t1w files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'jhu18m_to_pmd_t1w'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_t1w')

except:
    print('dataset_description exists ')

# %%
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_jhu_t1w', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using t1w images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'T1w-based template registration'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_jhu_t1w', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_fa files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'coreg_jhu_t1w'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_t1w')

except:
    print('dataset_description exists ')

# %%
# visualize t1w_based_template_registration_workflow
wf.write_graph(dotfilename=join(layout.root,'t1w_based_template_registration_workflow.dot'), format='png', simple_form=False)
from IPython.display import Image
Image(filename=join(layout.root,'t1w_based_template_registration_workflow.png'))
