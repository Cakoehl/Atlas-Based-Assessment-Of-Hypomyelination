# %% [markdown]
# # Hypomyelinating disorders:
# ### Multimodal-based registration pipeline for atlas-based quantitative magnetic resonance imaging (qMRI) assessment

# %% [markdown]
# This nipype workflow was created to analyse pediatric qMRI images of Pelizaeus Merzbacher-Disease patients
# 1. the workflow registers all imaging files on the T1-weighted (t1w) image within the session
# 2. patient to template registration was performed using multimodal-images, coregistered image files get warped to the template
# 3. a brain atlas segmentation from the template will transformed to the patient session space
# 4. processed outputfiles will appear in the derivatives folder

# %%
import bids
from tqdm import tqdm
import os
from os.path import join, isfile
from nipype import Workflow
from nipype.interfaces.utility import Split, Merge
from nipype.interfaces.utility import Rename
from nipype.interfaces.io import BIDSDataGrabber, DataSink
from wmi_nipype_workflows.wmi_nipype_workflows import register_to_mni
from nipype import Node, MapNode, Workflow, IdentityInterface, Function
from nipype.interfaces.ants import N4BiasFieldCorrection
from nipype.interfaces.ants.registration import RegistrationSynQuick
from nipype.interfaces.ants.resampling import ApplyTransforms
import os
# %matplotlib notebook

# %%
# set path for FSL, and ANTS package
os.environ["FSLDIR"] = "/opt/fsl/"
os.environ['ANTSPATH']='/opt/conda/bin/'

# %%
# select a patient-id and session-id for loading bids layout
subject='PMD1'
session='0m'

indexer=bids.layout.index.BIDSLayoutIndexer(validate=False, ignore=['code','tmp'])
layout = bids.BIDSLayout(os.path.dirname(os.getcwd()), derivatives=True, validate=False, indexer=indexer)

# %%
# configure inputqueries (all modalities to register) 
# file naming and file folders must follow BIDS standard
inputqueries = {
                't1w': dict(suffix='T1w', session=session, extension='nii.gz', acquisition=None, desc=None),
                'bval': dict(suffix='dwi', session=session, extension='bval' ),
                'dwi': dict(suffix='dwi', session=session, extension='nii.gz' ),
                'fa': dict(suffix='FA', session=session, extension='nii.gz', scope='derivatives', desc=None),
                't2w': dict(suffix='T2w', session=session, extension='nii.gz', acquisition=None, desc=None),   
         }
optional_queries={
                #'spgr': dict(suffix='T1w', session=session, extension='nii.gz', acquisition='SPGR'),
                #'mwf': dict(suffix='mwfmap', session=session, extension='nii.gz', scope='derivatives'),
                #'mrt': dict(suffix='mrtmap', session=session, extension='nii.gz', scope='derivatives'),
                #'qt1': dict(suffix='T1map', session=session, extension='nii.gz', scope='derivatives'),
                #'qt2': dict(suffix='T2map', session=session, extension='nii.gz', scope='derivatives'),
                #'mt': dict(suffix='MT', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'mtr': dict(suffix='MTR', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'ad': dict(suffix='AD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'rd': dict(suffix='RD', session=session, extension='nii.gz', scope='derivatives', desc=None),
                #'md': dict(suffix='MD', session=session, extension='nii.gz', scope='derivatives', desc=None),
}

# define a dictionary containg the reference image as key (use same keys as in queries) for coregister session images and 
# list of maps to apply the warpfield on for the individual qMRI modality 
ref_image_matcher={'b0': ['fa'],
                   't1w': None,
                   't2w': None,
                   #'spgr': ['mwf', 'qt1','qt2','mrt'], # mcdespot registration target (spgr) and mcdespot maps (MWF, qT1...)
                   #'mtr':['mt']                   
}

# load template as fixed (reference)images  default jhu18m 
# change the path for the T1w, T2w and a FA image as well as the atlas segmenation (mask) for using an alternativ atlas
load_fix = Node(IdentityInterface(fields=['t1','t2','fa','mask']), name='load_fix')
load_fix.inputs.t1= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t1_ss_lps.nii.gz')
load_fix.inputs.t2= join(layout.root,'code','templates','JHU_pediatric','18month','JHU_pediatric18_SS_t2ax_ss_lps.nii.gz')
load_fix.inputs.fa= join(layout.root,'code','templates','JHU_pediatric','18month', 'JHU_pediatric18_SS_fa_ss_lps.nii.gz')
load_fix.inputs.mask= join(layout.root,'code','templates','JHU_pediatric','18month','dil_ventricle_atlas18m.nii.gz')

# %%
# load files for every patient
in_files = {}
queries= inputqueries
queries.update(optional_queries)   
### STEP 1 coregistrater files within the session ####
inputnode = Node(IdentityInterface(list(queries.keys())), name='inputnode')
for key in queries.keys():
        # load input files according to dict
    in_files[key] = layout.get(**queries[key], return_type='file', subject=subject, invalid_filters='allow')
    inputnode.set_input(key, in_files[key])

# %%
# files found as specified for the inputnode
print(f'found files of subject: {subject}, session: {session} for co-registration to t1w image')
inputnode.inputs
# Out:
# found files of subject: PMD1, session: 0m for co-registration to t1w image
# bval = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD1/ses-0m/dwi/sub-PMD1_ses-0m_dwi.bval']
# dwi = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD1/ses-0m/dwi/sub-PMD1_ses-0m_dwi.nii.gz']
# fa = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/DWI/sub-PMD1/ses-0m/sub-PMD1_ses-0m_FA.nii.gz']
# t1w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_T1w.nii.gz']
# t2w = ['/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_T2w.nii.gz']

# %%
#squeeze= remove list from loaded files
for q in list(queries.keys()):
    squeezer= f'{q}_squeezer'
        
    globals()[squeezer]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeezer')
    #t1w_squeezer = Node(Split(splits=[1], squeeze=True), name='t1w_squeezer')

# %%
flat_list = []
for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:

                flat_list.append(v)
flat_list=list(set(flat_list))
flat_list
# Out:
# ['t1w', 'b0', 'fa', 't2w']

# %%
from wmi_nipype_workflows.wmi_nipype_workflows.brainextract_workflow import brain_extraction_wf
from nipype.interfaces.fsl.maths import ApplyMask
from nipype.interfaces.fsl import ImageMaths
from nipype.interfaces.fsl import BET
from nipype.interfaces.ants import N4BiasFieldCorrection
# brainextraction workflow --> robustvov get biascorrected T1w image 
brain_ex_t1 = brain_extraction_wf(report_dir=join(layout.root,'tmp','wmi_workflow_report'))
robustfov = brain_ex_t1.get_node('robustfov')
#bet = Node(BET(robust=True, mask=True, frac= 0.5), name='bet')
#bias_correction = Node(N4BiasFieldCorrection(), name="bias_correction" )

# %%
# get registration target spgrfa18 for registration of resulting mcdespot maps 
from dwi_target import get_dwi_target, get_mwf_target
mwf_target = get_mwf_target()

# %%
# generate a b0 image
b0_sink = Node(DataSink(base_directory=join(layout.root, 'derivatives', 'b0'),
                                     remove_dest_dir=True,
                                     parameterization=False),
                                     name='b0_sink')
b0_sink.inputs.container=join('sub-'+subject, 'ses-'+session)
                
# calculate b0 image for fa registration
from dti_b0 import b0_average
avg_b0 = Node(Function(input_names=['in_dwi', 'in_bval'],
                            output_names=['out_file'],
                            function=b0_average),
                         name='b0_avg')
rename_b0 = Node(Rename(format_string=("sub-{subject}_ses-{session}_space-{session}_b0"),
                                 keep_ext=True),
                          name='rename_b0')
rename_b0.inputs.subject_id= subject
rename_b0.inputs.session_id= session

# %%
coreg_sink = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_session'),
                                    remove_dest_dir=True,
                                    parameterization=False),
                            name='coreg_sink')         
coreg_sink.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
# nodes for coregister session 
for ref in list(ref_image_matcher.keys()):
    coreg= f'{ref}_coreg'
    rename_affine= f'{ref}_rename_affine'
    # nodes for coregister session 
    globals()[coreg]= Node(RegistrationSynQuick(transform_type="r"), name=f'{ref}_coreg')
    # nods for rename and save affine matrix from coregister session
    globals()[rename_affine]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-from{ref}_to_sessiont1w_xfm"),
                          keep_ext=True), name=f'{ref}_rename_affine')
    globals()[rename_affine].inputs.subject_id= subject
    globals()[rename_affine].inputs.session_id= session

# %%
# nodes for apply warp to quantitative maps
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            applyw= f'{qmrimap}_applyw'
            globals()[applyw]= Node(ApplyTransforms(), name=f'{qmrimap}_applyw')

# %%
# flatten list for ref_image_matcher.items()
flat_list = []

for xs in list(ref_image_matcher.keys()):
    flat_list.append(xs)
    #print(flat_list)
    for x in list(ref_image_matcher.values()):
        if x is not None:
            for v in x:
                #print('v', v)
                flat_list.append(v)
                #print(flat_list)
        
flat_list=list(set(flat_list))
flat_list
# Out:
# ['t1w', 'b0', 'fa', 't2w']

# %%
# adjust for different Image Dimension, otherwise brain mask cant be applied
from nilearn.image import resample_to_img
# create Node for resample all images to apply brainmask
def resampling(target, in_file): 
    import nibabel as nib
    from nilearn.image import resample_to_img
    from os.path import abspath, dirname, basename
    out_file = abspath('resampled_'+basename(in_file))
    resampled = resample_to_img(source_img=in_file, target_img=target)
    nib.save(resampled, out_file)
    return out_file

    
for image in flat_list:
    resample= f'{image}_resample'
    globals()[resample] = Node(Function(function=resampling,
                                       input_names=["target", "in_file"],
                                       output_names=["out_file"]),
                            name=f'{image}_resample')

# %%
## Apply the brainmask to the images which are registered within session
for image in flat_list:
    applymask= f'{image}_applymask'
    globals()[applymask] = Node(ApplyMask(), name=f'{image}_applymask')

# %%
for name in flat_list:
    rename= f'{name}_rename'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-t1w_desc-brainextracted_{name}"),
                          keep_ext=True), name=f'{name}_rename')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
#print(os.path.dirname(os.getcwd()))
layout.get(suffix='T2w', session=session, subject=subject,extension='nii.gz', acquisition=None, desc=None)
# Out:
# [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_T2w.nii.gz'>]

# %%
tmp = join(layout.root, 'tmp', 'multimod', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='coreg_pmd', base_dir=tmp)
# load files and remove list (squeeze)
for qname in list(queries.keys()):
    if qname == 'spgr':
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
                     #extract spgrfa18 from 4d file
                     (spgr_squeezer, mwf_target, [('out1', 'inputnode.in_file')]),
                  ])   
    else:
        wf.connect( [(inputnode, globals()[f'{qname}_squeezer'], [(f'{qname}','inlist')]),
         #[(inputnode, globals()[f'{qname}_squeezer'], [('t1w','inlist')]),
          ])
wf.connect( 
            # connect t1w image with brain extraction workflow use robustfov image as fixed image
            [(t1w_squeezer, brain_ex_t1, [('out1', 'inputnode.in_file')]),

             
             # b0 image calcuation for regsitering FA maps...
             (bval_squeezer, avg_b0, [('out1', 'in_bval')]),
             (dwi_squeezer, avg_b0, [('out1', 'in_dwi')]),
             (avg_b0, rename_b0, [('out_file', 'in_file')]),
             (rename_b0, b0_sink, [('out_file', '@b0')]),
             
 
            ])
# step 1 register images within the session to t1w image
for ref in list(ref_image_matcher.keys()):
    wf.connect( [( robustfov, globals()[f'{ref}_coreg'], [('out_roi','fixed_image')]),  

                 
                ])
    if ref=='spgr':
        wf.connect( [(mwf_target, spgr_coreg, [('outputnode.spgr_target','moving_image')]),
                    (spgr_coreg, spgr_rename_affine, [('out_matrix', 'in_file')]),
                    (spgr_rename_affine, coreg_sink, [('out_file', f'xfm.@spgr')]),
                    ])   
    elif ref=='b0':
        wf.connect( [(avg_b0, b0_coreg, [('out_file','moving_image')]),
                    (b0_coreg, b0_rename_affine, [('out_matrix', 'in_file')]),
                    (b0_rename_affine, coreg_sink, [('out_file', f'xfm.@b0')]),
                    ])       
    else:
        wf.connect( [(globals()[f'{ref}_squeezer'], globals()[f'{ref}_coreg'], [('out1','moving_image')]),
                     (globals()[f'{ref}_coreg'], globals()[f'{ref}_rename_affine'], [('out_matrix','in_file')]),
                     (globals()[f'{ref}_rename_affine'], coreg_sink, [('out_file', f'xfm.@{ref}')]),
                ])
# apply individual warpfields to qmri maps corresponding to ref_image_matcher 
for ref in list(ref_image_matcher.keys()):
    if ref_image_matcher[ref] is not None:
        for qmrimap in ref_image_matcher[ref]: 
            wf.connect( [( globals()[f'{ref}_coreg'], globals()[f'{qmrimap}_applyw'], [('out_matrix', 'transforms')]),
                         ( t1w_squeezer, globals()[f'{qmrimap}_applyw'], [('out1', 'reference_image')]),
                         ( globals()[f'{qmrimap}_squeezer'], globals()[f'{qmrimap}_applyw'], [('out1', 'input_image')]),

                        ])

for name in flat_list:                         
    if  name in list(ref_image_matcher.keys()):
       # resample ref_images
        wf.connect( [(globals()[f'{name}_coreg'], globals()[f'{name}_resample'], [('warped_image', 'in_file')]), 
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                      ])
    else: # resample all maps                     
        wf.connect( [(globals()[f'{name}_applyw'], globals()[f'{name}_resample'], [('output_image', 'in_file')]),
                     (t1w_squeezer, globals()[f'{name}_resample'], [('out1', 'target')]),
                    ])
# apply brainmask to all images
for name in flat_list:  
    wf.connect( [   
                     (globals()[f'{name}_resample'],globals()[f'{name}_applymask'], [('out_file', 'in_file')]), 
                         
                          #(bet, globals()[f'{qmrimap}_applymask'], [('mask_file', 'mask_file')]),
                         (brain_ex_t1, globals()[f'{name}_applymask'], [('outputnode.mask', 'mask_file')]),
                         
                         (globals()[f'{name}_applymask'],globals()[f'{name}_rename'], [('out_file', 'in_file')]), 
                         #(globals()[f'{qmrimap}_resample'], globals()[f'{qmrimap}_rename'], [('out_file', 'in_file')]), 
                         (globals()[f'{name}_rename'], coreg_sink, [('out_file', f'anat.@{name}')]),
                ])

# %%
# run nodes for registration workkflow step 1
wf.run()
# Out:
# 240131-13:09:09,150 nipype.workflow INFO:
# 	 Workflow coreg_pmd settings: ['check', 'execution', 'logging', 'monitoring']
# 240131-13:09:09,396 nipype.workflow INFO:
# 	 Running serially.
# 240131-13:09:09,397 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_squeezer".
# 240131-13:09:09,399 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_squeezer" - collecting precomputed outputs
# 240131-13:09:09,400 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_squeezer" found cached.
# 240131-13:09:09,400 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.bval_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/bval_squeezer".
# 240131-13:09:09,401 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.bval_squeezer" - collecting precomputed outputs
# 240131-13:09:09,402 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.bval_squeezer" found cached.
# 240131-13:09:09,403 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.dwi_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/dwi_squeezer".
# 240131-13:09:09,404 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.dwi_squeezer" - collecting precomputed outputs
# 240131-13:09:09,404 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.dwi_squeezer" found cached.
# 240131-13:09:09,405 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/fa_squeezer".
# 240131-13:09:09,424 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.fa_squeezer" - collecting precomputed outputs
# 240131-13:09:09,425 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.fa_squeezer" found cached.
# 240131-13:09:09,425 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_squeezer" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_squeezer".
# 240131-13:09:09,427 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_squeezer" - collecting precomputed outputs
# 240131-13:09:09,427 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_squeezer" found cached.
# 240131-13:09:09,428 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.n4correction" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/n4correction".
# 240131-13:09:09,430 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.n4correction" - collecting precomputed outputs
# 240131-13:09:09,430 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.n4correction" found cached.
# 240131-13:09:09,431 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.subject_id_node" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/subject_id_node".
# 240131-13:09:09,446 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.subject_id_node" - collecting precomputed outputs
# 240131-13:09:09,447 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.subject_id_node" found cached.
# 240131-13:09:09,448 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_avg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_avg".
# 240131-13:09:09,452 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_avg" - collecting precomputed outputs
# 240131-13:09:09,452 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_avg" found cached.
# 240131-13:09:09,453 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.robustfov" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/robustfov".
# 240131-13:09:09,474 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.robustfov" - collecting precomputed outputs
# 240131-13:09:09,475 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.robustfov" found cached.
# 240131-13:09:09,476 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.rename_b0" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/rename_b0".
# 240131-13:09:09,479 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.rename_b0" - collecting precomputed outputs
# 240131-13:09:09,480 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.rename_b0" found cached.
# 240131-13:09:09,480 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_coreg".
# 240131-13:09:09,493 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_coreg" - collecting precomputed outputs
# 240131-13:09:09,494 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_coreg" found cached.
# 240131-13:09:09,495 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_coreg".
# 240131-13:09:09,499 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_coreg" - collecting precomputed outputs
# 240131-13:09:09,499 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_coreg" found cached.
# 240131-13:09:09,500 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_coreg" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_coreg".
# 240131-13:09:09,504 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_coreg" - collecting precomputed outputs
# 240131-13:09:09,505 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_coreg" found cached.
# 240131-13:09:09,506 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.bet" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/bet".
# 240131-13:09:09,521 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.bet" - collecting precomputed outputs
# 240131-13:09:09,522 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.bet" found cached.
# 240131-13:09:09,523 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_sink" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_sink".
# 240131-13:09:09,527 nipype.workflow INFO:
# 	 [Node] Executing "b0_sink" <nipype.interfaces.io.DataSink>
# 240131-13:09:09,552 nipype.workflow INFO:
# 	 [Node] Finished "b0_sink", elapsed time 0.023109s.
# 240131-13:09:09,555 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_rename_affine" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_rename_affine".
# 240131-13:09:09,558 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_rename_affine" - collecting precomputed outputs
# 240131-13:09:09,559 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_rename_affine" found cached.
# 240131-13:09:09,560 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_applyw" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/fa_applyw".
# 240131-13:09:09,563 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.fa_applyw" - collecting precomputed outputs
# 240131-13:09:09,564 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.fa_applyw" found cached.
# 240131-13:09:09,565 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_resample" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_resample".
# 240131-13:09:09,568 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_resample" - collecting precomputed outputs
# 240131-13:09:09,569 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_resample" found cached.
# 240131-13:09:09,570 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_rename_affine" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_rename_affine".
# 240131-13:09:09,573 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_rename_affine" - collecting precomputed outputs
# 240131-13:09:09,574 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_rename_affine" found cached.
# 240131-13:09:09,575 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_resample" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_resample".
# 240131-13:09:09,577 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_resample" - collecting precomputed outputs
# 240131-13:09:09,578 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_resample" found cached.
# 240131-13:09:09,579 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_rename_affine" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_rename_affine".
# 240131-13:09:09,582 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_rename_affine" - collecting precomputed outputs
# 240131-13:09:09,582 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_rename_affine" found cached.
# 240131-13:09:09,583 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_resample" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_resample".
# 240131-13:09:09,586 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_resample" - collecting precomputed outputs
# 240131-13:09:09,587 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_resample" found cached.
# 240131-13:09:09,587 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.warpback" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/warpback".
# 240131-13:09:09,609 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.warpback" - collecting precomputed outputs
# 240131-13:09:09,610 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.warpback" found cached.
# 240131-13:09:09,611 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_resample" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/fa_resample".
# 240131-13:09:09,613 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.fa_resample" - collecting precomputed outputs
# 240131-13:09:09,614 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.fa_resample" found cached.
# 240131-13:09:09,615 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.applymask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/applymask".
# 240131-13:09:09,622 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.applymask" - collecting precomputed outputs
# 240131-13:09:09,623 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.applymask" found cached.
# 240131-13:09:09,624 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.brain_extraction.reportnode" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/brain_extraction/reportnode".
# 240131-13:09:09,627 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.brain_extraction.reportnode" - collecting precomputed outputs
# 240131-13:09:09,628 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.brain_extraction.reportnode" found cached.
# 240131-13:09:09,629 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_applymask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_applymask".
# 240131-13:09:09,637 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_applymask" - collecting precomputed outputs
# 240131-13:09:09,637 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_applymask" found cached.
# 240131-13:09:09,638 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_applymask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_applymask".
# 240131-13:09:09,669 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_applymask" - collecting precomputed outputs
# 240131-13:09:09,669 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_applymask" found cached.
# 240131-13:09:09,670 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_applymask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_applymask".
# 240131-13:09:09,693 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_applymask" - collecting precomputed outputs
# 240131-13:09:09,694 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_applymask" found cached.
# 240131-13:09:09,695 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_applymask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/fa_applymask".
# 240131-13:09:09,698 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.fa_applymask" - collecting precomputed outputs
# 240131-13:09:09,699 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.fa_applymask" found cached.
# 240131-13:09:09,700 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t1w_rename" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t1w_rename".
# 240131-13:09:09,703 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t1w_rename" - collecting precomputed outputs
# 240131-13:09:09,703 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t1w_rename" found cached.
# 240131-13:09:09,704 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.b0_rename" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/b0_rename".
# 240131-13:09:09,722 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.b0_rename" - collecting precomputed outputs
# 240131-13:09:09,723 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.b0_rename" found cached.
# 240131-13:09:09,724 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.t2w_rename" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/t2w_rename".
# 240131-13:09:09,726 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.t2w_rename" - collecting precomputed outputs
# 240131-13:09:09,727 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.t2w_rename" found cached.
# 240131-13:09:09,728 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.fa_rename" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/fa_rename".
# 240131-13:09:09,730 nipype.workflow INFO:
# 	 [Node] Cached "coreg_pmd.fa_rename" - collecting precomputed outputs
# 240131-13:09:09,731 nipype.workflow INFO:
# 	 [Node] "coreg_pmd.fa_rename" found cached.
# 240131-13:09:09,732 nipype.workflow INFO:
# 	 [Node] Setting-up "coreg_pmd.coreg_sink" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/coreg_pmd/coreg_sink".
# 240131-13:09:09,742 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "coreg_pmd.coreg_sink".
# 240131-13:09:09,745 nipype.workflow INFO:
# 	 [Node] Executing "coreg_sink" <nipype.interfaces.io.DataSink>
# 240131-13:09:10,215 nipype.workflow INFO:
# 	 [Node] Finished "coreg_sink", elapsed time 0.468115s.

# %%
# create a dataset_description.json for derivatives 'coreg_session'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_session', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
        'Name': 'register session files on t1w image',
        'BIDSVersion': '1.4.0',
        'DatasetType': 'derivative',
        'GeneratedBy': [{'caroline.koehler@ukdd.de': 'co-register session images to T1-weighted image of the session'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_session', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_session Workflow')
# update layout otherwise coreg_session files are not found)

try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'coreg_session'))
    print ('writing dataset_description for derivatives coreg_session')

except:
    print('dataset_description exists ')
# Out:
# dataset_description exists

# %%
print('warp atlas in PMD space')
### STEP2: warp the jhu18m atlas in pmd patient space ###
print('reload bids layout')
layout2 = bids.BIDSLayout(layout.root, derivatives=True, validate=False, ignore=['code', 'tmp','tmp_t1w','tmp_fa','tmp_multimod'])
# Out:
# warp atlas in PMD space
# reload bids layout
# /opt/conda/lib/python3.9/site-packages/bids/layout/validation.py:48: UserWarning: The ability to pass arguments to BIDSLayout that control indexing is likely to be removed in future; possibly as early as PyBIDS 0.14. This includes the `config_filename`, `ignore`, `force_index`, and `index_metadata` arguments. The recommended usage pattern is to initialize a new BIDSLayoutIndexer with these arguments, and pass it to the BIDSLayout via the `indexer` argument.
#   warnings.warn("The ability to pass arguments to BIDSLayout that control "

# %%
flat_list
# Out:
# ['t1w', 'b0', 'fa', 't2w']

# %%
load_coreg = Node(IdentityInterface(flat_list), name='inputnode2')
for name in flat_list:
    in_files= layout2.get(suffix=name, subject=subject,session=session, acquisition=None, scope='derivatives', desc='brainextracted', extension='nii.gz')
    load_coreg.set_input(name, in_files)

# %%
# shows all found coregistered and brainextracted images of the subject and session
print(f'list of files found for registration step 2 of subject:{subject}' )
load_coreg.inputs
# Out:
# list of files found for registration step 2 of subject:PMD1
# b0 = [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/coreg_session/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_space-t1w_desc-brainextracted_b0.nii.gz'>]
# fa = [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/coreg_session/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_space-t1w_desc-brainextracted_fa.nii.gz'>]
# t1w = [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/coreg_session/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_space-t1w_desc-brainextracted_t1w.nii.gz'>]
# t2w = [<BIDSImageFile filename='/home/jovyan/work/atlas-based-assessment-of-hypomyelination/derivatives/coreg_session/sub-PMD1/ses-0m/anat/sub-PMD1_ses-0m_space-t1w_desc-brainextracted_t2w.nii.gz'>]

# %%
# create multiple nodes squeeze= remove list from loaded files
for q in flat_list:
    squeez= f'{q}_squeez'
    globals()[squeez]= Node(Split(splits=[1], squeeze=True), name= f'{q}_squeez')

# %%
# merge fixed and moving images for multimodal registration (make a list of multimodal images)
jhu_images = Node(Merge(3), name='fix_images')
pmd_mov=Node(Merge(3), name='pmd_mov')

# %%
# merge files to list
merge_inputs=len(flat_list)# dynamic number of connections in for merge node
pmd_coregimages=Node(Merge(merge_inputs), name='pmd_coregimages') # make a list of images to use Mapnodes

# %%
# apply inverse warp field on jhu atlas/ mask
# this workflow register the moving image to a template (reference image) and apply an inverse transform to the atlas segmentation
# this warps the altas segmentation in the patient session space 
# Additionally, pmd_coreg_images get warped to jhu template
from wmi_nipype_workflows.wmi_nipype_workflows.register_to_mni import mask_to_patient_space
mask_to_pmd = mask_to_patient_space()
# because reference_image is a list, mask to pmd is not working. provide single reference file for applytransforms via disconnect
inputnode= mask_to_pmd.get_node('inputnode')
apply_inv_transforms= mask_to_pmd.get_node('apply_inv_transforms')
mask_to_pmd.disconnect([(inputnode, apply_inv_transforms, [('moving_image', 'reference_image')]),])
split_reference= Node(Split(), name= 'split_reference')
split_reference.inputs.splits= [1,1,1]
split_reference.inputs.squeeze= True
mask_to_pmd.connect([(inputnode, split_reference, [('moving_image', 'inlist')]),
                     (split_reference, apply_inv_transforms,[('out1', 'reference_image')]),   
                    ])

# %%
# split inv_mask because it is a list (mapnode)
split_inv_mask= Node(Split(), name= 'split_inv_mask')
split_inv_mask.inputs.splits= [1]
split_inv_mask.inputs.squeeze= True

# %%
# apply transforms on pmd_coregimages
# all coregistered files are also moved to template space fascilitating patient comparison
from nipype.interfaces.ants import ApplyTransforms, RegistrationSynQuick
apply_transforms_forw= MapNode(ApplyTransforms(), name = 'apply_transforms_forw', iterfield = ['input_image'])
transforms = Node(Merge(2), name='transforms')
split_pmd_forw = Node(Split(), name= 'split_pmd_forw')
split_pmd_forw.inputs.splits= [1]*merge_inputs
split_pmd_forw.inputs.squeeze= True

# %%
# rename and save jhu18m atlas/mask in pmd space
jhu_to_pmd_multimod = Node(DataSink(base_directory=join(layout.root,'derivatives', 'jhu18m_to_pmd_multimod'),
                           remove_dest_dir=True,
                            parameterization=False), name='jhu_to_pmd_multimod')
jhu_to_pmd_multimod.inputs.container=join('sub-'+subject, 'ses-'+session) 



rename_atlas = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-{session}_desc-jhu18m_label-regmultimod_mask"),
                        keep_ext=True),
                        name='rename_atlas')
rename_atlas.inputs.subject_id= subject
rename_atlas.inputs.session_id= session

coreg_jhu_multimod = Node(DataSink(base_directory=join(layout.root,'derivatives', 'coreg_jhu_multimod'),
                                 remove_dest_dir=True,
                                 parameterization=False), name='coreg_jhu_multimod')
coreg_jhu_multimod.inputs.container=join('sub-'+subject, 'ses-'+session)

# %%
for name in flat_list:
    rename= f'{name}_rename_jhu'
    globals()[rename]= Node(Rename(format_string=(f"sub-{subject}_ses-{session}_space-jhu_desc-regmultimod_{name}"),
                          keep_ext=True), name=f'{name}_rename_jhu')
    globals()[rename].inputs.subject_id= subject
    globals()[rename].inputs.session_id= session

# %%
# warp files to register fa from pmd space to jhu18m atlas space
rename_jhu_affine = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdmultimod_to-jhumultimod_desc-affine_xfm"),
                        keep_ext=True),
           name='rename_jhu_affine')
rename_jhu_affine.inputs.subject_id= subject
rename_jhu_affine.inputs.session_id= session

rename_jhu_forwardwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdmultimod_to-jhumultimod_desc-forward_xfm"),
                         keep_ext=True),
  name='rename_jhu_forwardwarp')
rename_jhu_forwardwarp.inputs.subject_id= subject
rename_jhu_forwardwarp.inputs.session_id= session

rename_jhu_invwarp = Node(Rename(format_string=(f"sub-{subject}_ses-{session}_from-pmdmultimod_to-jhumultimod_desc-inverse_xfm"),
                       keep_ext=True),
           name='rename_jhu_invwarp')
rename_jhu_invwarp.inputs.subject_id= subject
rename_jhu_invwarp.inputs.session_id= session

# %%
#connect the nodes for registration step 2
tmp = join(layout.root, 'tmp','multimod', f'sub-{subject}', f'ses-{session}')
wf = Workflow(name='mask_to_patient_space_multimod', base_dir=tmp)

wf.connect([(load_coreg, t1w_squeez , [('t1w', 'inlist')]),
            # load files jhu18m & pmd and merge them as list 
            (load_fix, jhu_images, [('t1', 'in1'),
                                    ('t2', 'in2'),
                                    ('fa', 'in3')]), 
            (load_coreg, pmd_mov, [('t1w', 'in1'),
                                 ('t2w', 'in2'),
                                 ('fa', 'in3')]),
            
            ])

# merge all coregistered files in a list except registration target 

for count, name in enumerate(flat_list):
    wf.connect([(load_coreg, pmd_coregimages, [(name, f'in{count+1}')])
                ])
    
wf.connect([(jhu_images, mask_to_pmd, [('out', 'inputnode.fixed_image')]),
            # t1w registration pmd to jhu18m, apply inv warp to altas and save atlas in pmd space 
            (pmd_mov, mask_to_pmd, [('out', 'inputnode.moving_image')]),   
                        (load_fix, mask_to_pmd, [('mask', 'inputnode.mask')]),   
                        (mask_to_pmd, split_inv_mask, [('outputnode.inv_mask', 'inlist')]),  
                        (split_inv_mask, rename_atlas, [('out1', 'in_file')]),  
                        (rename_atlas, jhu_to_pmd_multimod, [('out_file', '@atlas')]),
            # apply registration on PMD coregimages to jhu space
                        (mask_to_pmd, transforms, [('outputnode.affine_matrix', 'in2'),
                                                   ('outputnode.forward_warp_field', 'in1')]),
                        (transforms, apply_transforms_forw, [('out', 'transforms')]),
                        (pmd_coregimages, apply_transforms_forw, [('out', 'input_image')]),
                        (load_fix, apply_transforms_forw, [('t1', 'reference_image')]),  
                        (apply_transforms_forw, split_pmd_forw, [('output_image', 'inlist')]),
        ])
# save and rename coregimages in jhu space
for count, name in enumerate(flat_list):
    wf.connect([(split_pmd_forw, globals()[f'{name}_rename_jhu'], [(f'out{count+1}', 'in_file')]),
                (globals()[f'{name}_rename_jhu'], coreg_jhu_multimod , [('out_file', f'anat.@{name}')]),
               ])
# save warpfiles for  registration from pmd to jhu space 
wf.connect([(mask_to_pmd, rename_jhu_affine, [('outputnode.affine_matrix', 'in_file')]),
            (rename_jhu_affine, coreg_jhu_multimod , [('out_file', 'xfm.@multimod')]),
            (mask_to_pmd, rename_jhu_forwardwarp, [('outputnode.forward_warp_field', 'in_file')]),
            (rename_jhu_forwardwarp, coreg_jhu_multimod , [('out_file', 'xfm.@forward')]),
            (mask_to_pmd, rename_jhu_invwarp, [('outputnode.inverse_warp_field', 'in_file')]),
            (rename_jhu_invwarp, coreg_jhu_multimod , [('out_file', 'xfm.@inverse')]),
           ])

# %%
# start the registration pipeline
wf.run()
# Out:
# 240131-13:09:12,199 nipype.workflow INFO:
# 	 Workflow mask_to_patient_space_multimod settings: ['check', 'execution', 'logging', 'monitoring']
# 240131-13:09:12,281 nipype.workflow INFO:
# 	 Running serially.
# 240131-13:09:12,283 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.t1w_squeez" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/t1w_squeez".
# 240131-13:09:12,297 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.t1w_squeez" - collecting precomputed outputs
# 240131-13:09:12,298 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.t1w_squeez" found cached.
# 240131-13:09:12,299 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.fix_images" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/fix_images".
# 240131-13:09:12,303 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.fix_images" - collecting precomputed outputs
# 240131-13:09:12,304 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.fix_images" found cached.
# 240131-13:09:12,305 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.pmd_mov" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/pmd_mov".
# 240131-13:09:12,309 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.pmd_mov" - collecting precomputed outputs
# 240131-13:09:12,310 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.pmd_mov" found cached.
# 240131-13:09:12,312 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.pmd_coregimages" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/pmd_coregimages".
# 240131-13:09:12,314 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.pmd_coregimages".
# 240131-13:09:12,321 nipype.workflow INFO:
# 	 [Node] Executing "pmd_coregimages" <nipype.interfaces.utility.base.Merge>
# 240131-13:09:12,324 nipype.workflow INFO:
# 	 [Node] Finished "pmd_coregimages", elapsed time 0.000434s.
# 240131-13:09:12,329 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.mask_to_patient_space.warpnode" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/mask_to_patient_space/warpnode".
# 240131-13:09:12,372 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.mask_to_patient_space.warpnode" - collecting precomputed outputs
# 240131-13:09:12,373 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.mask_to_patient_space.warpnode" found cached.
# 240131-13:09:12,374 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.mask_to_patient_space.split_reference" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/mask_to_patient_space/split_reference".
# 240131-13:09:12,390 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.mask_to_patient_space.split_reference" - collecting precomputed outputs
# 240131-13:09:12,391 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.mask_to_patient_space.split_reference" found cached.
# 240131-13:09:12,392 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.mask_to_patient_space.transforms" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/mask_to_patient_space/transforms".
# 240131-13:09:12,398 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.mask_to_patient_space.transforms" - collecting precomputed outputs
# 240131-13:09:12,399 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.mask_to_patient_space.transforms" found cached.
# 240131-13:09:12,400 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.transforms" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/transforms".
# 240131-13:09:12,406 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.transforms" - collecting precomputed outputs
# 240131-13:09:12,407 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.transforms" found cached.
# 240131-13:09:12,408 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.rename_jhu_affine" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/rename_jhu_affine".
# 240131-13:09:12,414 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.rename_jhu_affine" - collecting precomputed outputs
# 240131-13:09:12,415 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.rename_jhu_affine" found cached.
# 240131-13:09:12,416 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.rename_jhu_forwardwarp" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/rename_jhu_forwardwarp".
# 240131-13:09:12,422 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.rename_jhu_forwardwarp" - collecting precomputed outputs
# 240131-13:09:12,423 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.rename_jhu_forwardwarp" found cached.
# 240131-13:09:12,424 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.rename_jhu_invwarp" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/rename_jhu_invwarp".
# 240131-13:09:12,430 nipype.workflow INFO:
# 	 [Node] Cached "mask_to_patient_space_multimod.rename_jhu_invwarp" - collecting precomputed outputs
# 240131-13:09:12,431 nipype.workflow INFO:
# 	 [Node] "mask_to_patient_space_multimod.rename_jhu_invwarp" found cached.
# 240131-13:09:12,440 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.mask_to_patient_space.apply_inv_transforms".
# 240131-13:09:12,448 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_inv_transforms0" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/mask_to_patient_space/apply_inv_transforms/mapflow/_apply_inv_transforms0".
# 240131-13:09:12,450 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_apply_inv_transforms0".
# 240131-13:09:12,454 nipype.workflow INFO:
# 	 [Node] Executing "_apply_inv_transforms0" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 240131-13:09:15,496 nipype.workflow INFO:
# 	 [Node] Finished "_apply_inv_transforms0", elapsed time 3.037446s.
# 240131-13:09:15,504 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.apply_transforms_forw".
# 240131-13:09:15,507 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_transforms_forw0" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/apply_transforms_forw/mapflow/_apply_transforms_forw0".
# 240131-13:09:15,510 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_apply_transforms_forw0".
# 240131-13:09:15,515 nipype.workflow INFO:
# 	 [Node] Executing "_apply_transforms_forw0" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 240131-13:09:18,0 nipype.workflow INFO:
# 	 [Node] Finished "_apply_transforms_forw0", elapsed time 2.480576s.
# 240131-13:09:18,5 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_transforms_forw1" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/apply_transforms_forw/mapflow/_apply_transforms_forw1".
# 240131-13:09:18,6 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_apply_transforms_forw1".
# 240131-13:09:18,9 nipype.workflow INFO:
# 	 [Node] Executing "_apply_transforms_forw1" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 240131-13:09:20,218 nipype.workflow INFO:
# 	 [Node] Finished "_apply_transforms_forw1", elapsed time 2.206311s.
# 240131-13:09:20,222 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_transforms_forw2" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/apply_transforms_forw/mapflow/_apply_transforms_forw2".
# 240131-13:09:20,224 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_apply_transforms_forw2".
# 240131-13:09:20,229 nipype.workflow INFO:
# 	 [Node] Executing "_apply_transforms_forw2" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 240131-13:09:22,388 nipype.workflow INFO:
# 	 [Node] Finished "_apply_transforms_forw2", elapsed time 2.154045s.
# 240131-13:09:22,396 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_transforms_forw3" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/apply_transforms_forw/mapflow/_apply_transforms_forw3".
# 240131-13:09:22,398 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_apply_transforms_forw3".
# 240131-13:09:22,403 nipype.workflow INFO:
# 	 [Node] Executing "_apply_transforms_forw3" <nipype.interfaces.ants.resampling.ApplyTransforms>
# 240131-13:09:24,628 nipype.workflow INFO:
# 	 [Node] Finished "_apply_transforms_forw3", elapsed time 2.221024s.
# 240131-13:09:24,634 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.split_inv_mask" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/split_inv_mask".
# 240131-13:09:24,636 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.split_inv_mask".
# 240131-13:09:24,640 nipype.workflow INFO:
# 	 [Node] Executing "split_inv_mask" <nipype.interfaces.utility.base.Split>
# 240131-13:09:24,643 nipype.workflow INFO:
# 	 [Node] Finished "split_inv_mask", elapsed time 0.000815s.
# 240131-13:09:24,647 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.split_pmd_forw" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/split_pmd_forw".
# 240131-13:09:24,649 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.split_pmd_forw".
# 240131-13:09:24,653 nipype.workflow INFO:
# 	 [Node] Executing "split_pmd_forw" <nipype.interfaces.utility.base.Split>
# 240131-13:09:24,656 nipype.workflow INFO:
# 	 [Node] Finished "split_pmd_forw", elapsed time 0.000772s.
# 240131-13:09:24,659 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.rename_atlas" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/rename_atlas".
# 240131-13:09:24,661 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.rename_atlas".
# 240131-13:09:24,664 nipype.workflow INFO:
# 	 [Node] Executing "rename_atlas" <nipype.interfaces.utility.base.Rename>
# 240131-13:09:24,667 nipype.workflow INFO:
# 	 [Node] Finished "rename_atlas", elapsed time 0.000887s.
# 240131-13:09:24,670 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.t1w_rename_jhu" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/t1w_rename_jhu".
# 240131-13:09:24,673 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.t1w_rename_jhu".
# 240131-13:09:24,676 nipype.workflow INFO:
# 	 [Node] Executing "t1w_rename_jhu" <nipype.interfaces.utility.base.Rename>
# 240131-13:09:24,679 nipype.workflow INFO:
# 	 [Node] Finished "t1w_rename_jhu", elapsed time 0.000911s.
# 240131-13:09:24,682 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.b0_rename_jhu" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/b0_rename_jhu".
# 240131-13:09:24,685 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.b0_rename_jhu".
# 240131-13:09:24,688 nipype.workflow INFO:
# 	 [Node] Executing "b0_rename_jhu" <nipype.interfaces.utility.base.Rename>
# 240131-13:09:24,691 nipype.workflow INFO:
# 	 [Node] Finished "b0_rename_jhu", elapsed time 0.000871s.
# 240131-13:09:24,694 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.fa_rename_jhu" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/fa_rename_jhu".
# 240131-13:09:24,714 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.fa_rename_jhu".
# 240131-13:09:24,718 nipype.workflow INFO:
# 	 [Node] Executing "fa_rename_jhu" <nipype.interfaces.utility.base.Rename>
# 240131-13:09:24,722 nipype.workflow INFO:
# 	 [Node] Finished "fa_rename_jhu", elapsed time 0.001118s.
# 240131-13:09:24,726 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.t2w_rename_jhu" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/t2w_rename_jhu".
# 240131-13:09:24,745 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.t2w_rename_jhu".
# 240131-13:09:24,750 nipype.workflow INFO:
# 	 [Node] Executing "t2w_rename_jhu" <nipype.interfaces.utility.base.Rename>
# 240131-13:09:24,754 nipype.workflow INFO:
# 	 [Node] Finished "t2w_rename_jhu", elapsed time 0.001128s.
# 240131-13:09:24,758 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.jhu_to_pmd_multimod" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/jhu_to_pmd_multimod".
# 240131-13:09:24,761 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.jhu_to_pmd_multimod".
# 240131-13:09:24,766 nipype.workflow INFO:
# 	 [Node] Executing "jhu_to_pmd_multimod" <nipype.interfaces.io.DataSink>
# 240131-13:09:24,801 nipype.workflow INFO:
# 	 [Node] Finished "jhu_to_pmd_multimod", elapsed time 0.032523s.
# 240131-13:09:24,806 nipype.workflow INFO:
# 	 [Node] Setting-up "mask_to_patient_space_multimod.coreg_jhu_multimod" in "/home/jovyan/work/atlas-based-assessment-of-hypomyelination/tmp/multimod/sub-PMD1/ses-0m/mask_to_patient_space_multimod/coreg_jhu_multimod".
# 240131-13:09:24,815 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "mask_to_patient_space_multimod.coreg_jhu_multimod".
# 240131-13:09:24,822 nipype.workflow INFO:
# 	 [Node] Executing "coreg_jhu_multimod" <nipype.interfaces.io.DataSink>
# 240131-13:09:25,199 nipype.workflow INFO:
# 	 [Node] Finished "coreg_jhu_multimod", elapsed time 0.37473s.

# %%
# create a dataset_description.json for derivatives 'jhu18m_to_pmd_t1w'
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_multimod', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using t1w images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'FA-based template registration'}]
    }))

with open(join(layout.root, 'derivatives', 'jhu18m_to_pmd_multimod', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_t1w files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'jhu18m_to_pmd_multimod'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_t1w')

except:
    print('dataset_description exists ')
# Out:
# dataset_description exists

# %%
import time
import json
__version__ = "0.2"
with open(join(layout.root, 'derivatives', 'coreg_jhu_multimod', 'dataset_description.json'), 'w') as f:
    f.write(json.dumps({
                'Name': 'register session files to template using multimodal images',
                'BIDSVersion': '1.4.0',
                'DatasetType': 'derivative',
                'GeneratedBy': [{'caroline.koehler@ukdd.de': 'multimodal-based template registration'}]
    }))

with open(join(layout.root, 'derivatives', 'coreg_jhu_multimod', 'CHANGELOG'), 'a') as f:
    f.write('\n')
    f.write(time.strftime("%Y-%m-%d:"))
    f.write('\t-Running reg_template Workflow')
# update layout otherwise jhu18m_to_pmd_fa files are not found)
try:
    layout.add_derivatives(path= join(layout.root, 'derivatives', 'coreg_jhu_multimod'))
    print ('writing dataset_description for derivatives jhu18m_to_pmd_mulimod')

except:
    print('dataset_description exists ')
# Out:
# dataset_description exists

# %%
wf.write_graph(dotfilename=join(layout.root,'multimodal_based_template_registration_workflow.dot'), format='png', simple_form=False)
from IPython.display import Image
Image(filename=join(layout.root,'multimodal_based_template_registration_workflow.png'))
# Out:
# 240131-13:09:25,760 nipype.workflow INFO:
# 	 Generated workflow graph: /home/jovyan/work/atlas-based-assessment-of-hypomyelination/multimodal_based_template_registration_workflow.png (graph2use=hierarchical, simple_form=False).
